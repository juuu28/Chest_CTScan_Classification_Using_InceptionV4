# %%
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt
import os
from tensorflow import keras
from keras.models import Model
from tensorflow.keras import layers
from keras.layers import concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from keras.layers import Conv2D , MaxPool2D , Input , GlobalAveragePooling2D ,AveragePooling2D, Dense , Dropout ,Activation , BatchNormalization
# Out:
# 2023-12-01 20:40:01.582938: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-01 20:40:01.634486: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 20:40:01.634517: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 20:40:01.634523: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 20:40:01.642164: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
def train_val_generators(TRAINING_DIR, TEST_DIR):

  train_datagen = ImageDataGenerator(rescale=1./255,
                                     rotation_range=10,      # Rotate images by up to 40 degrees
                                     width_shift_range=0.2,  # Shift width by up to 20%
                                     height_shift_range=0.2, # Shift height by up to 20%
                                     shear_range=0.2,        # Shear angle by up to 20%
                                     zoom_range=0.2,         # Zoom in/out by up to 20%
                                     horizontal_flip=True,   # Flip horizontally
                                     fill_mode='nearest')
  train_generator = train_datagen.flow_from_directory(directory=TRAINING_DIR,
                                                      batch_size=32,
                                                      class_mode='categorical',
                                                      target_size=(224, 224))
  validation_datagen = ImageDataGenerator(rescale=1/255)
  

  test_datagen = ImageDataGenerator(rescale=1/255, 
                                   validation_split=0.4)
  validation_generator = test_datagen.flow_from_directory(directory=TEST_DIR,
                                                                batch_size=32,
                                                                class_mode='categorical',
                                                                target_size=(224, 224),
                                                                subset='validation')
  test_generator = test_datagen.flow_from_directory(directory=TEST_DIR,
                                                                batch_size=256,
                                                                class_mode='categorical',
                                                                target_size=(224, 224), 
                                                                subset='training')

  return train_generator, validation_generator, test_generator

# %%
train_generator, validation_generator, test_generator = train_val_generators('Chest_CTScan_dataset-main/train', 'Chest_CTScan_dataset-main/test')
# Out:
# Found 613 images belonging to 4 classes.
# Found 125 images belonging to 4 classes.
# Found 190 images belonging to 4 classes.

# %%
# Menghitung jumlah data per kelas
num_classes_train = len(train_generator.class_indices)
class_counts_train = np.zeros(num_classes_train)

for i in range(len(train_generator)):
    batch_labels_train = np.argmax(train_generator[i][1], axis=1)
    class_counts_train += np.bincount(batch_labels_train, minlength=num_classes)

# Mendapatkan nama kelas
class_names_train = list(train_generator.class_indices.keys())

plt.bar(class_names_train, class_counts_train)
plt.title('Distribusi Kelas Gambar Latih')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.xticks(rotation=90)
plt.show()

# %%
print(class_names_train, class_counts_train)
# Out:
# ['adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib', 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa', 'normal', 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa'] [195. 115. 148. 155.]

# %%
# Menghitung jumlah data per kelas
num_classes_val = len(validation_generator.class_indices)
class_counts_val = np.zeros(num_classes_val)

for i in range(len(validation_generator)):
    batch_labels_val = np.argmax(validation_generator[i][1], axis=1)
    class_counts_val += np.bincount(batch_labels_val, minlength=num_classes)

# Mendapatkan nama kelas
class_names_val = list(validation_generator.class_indices.keys())

plt.bar(class_names_val, class_counts_val)
plt.title('Distribusi Kelas Gambar Validasi')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.xticks(rotation=90)
plt.show()

# %%
print(class_names_val, class_counts_val)
# Out:
# ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma'] [48. 20. 21. 36.]

# %%
# Menghitung jumlah data per kelas
num_classes_test = len(test_generator.class_indices)
class_counts_test = np.zeros(num_classes_test)

for i in range(len(test_generator)):
    batch_labels_test = np.argmax(test_generator[i][1], axis=1)
    class_counts_test += np.bincount(batch_labels_test, minlength=num_classes)

# Mendapatkan nama kelas
class_names_test = list(test_generator.class_indices.keys())

plt.bar(class_names_test, class_counts_test)
plt.title('Distribusi Kelas Gambar Uji')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.xticks(rotation=90)
plt.show()

# %%
print(class_names_test, class_counts_test)
# Out:
# ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma'] [72. 31. 33. 54.]

# %%
def InceptionV4():

    input_layer = Input(shape=(224 , 224 , 3))

    x = stemBlock(prev_layer=input_layer)

    x = InceptionBlock_A(prev_layer=x)
    x = InceptionBlock_A(prev_layer=x)
    x = InceptionBlock_A(prev_layer=x)
    x = InceptionBlock_A(prev_layer=x)

    x = reduction_A_Block(prev_layer=x)

    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)

    x = reduction_B_Block(prev_layer= x)

    x = InceptionBlock_C(prev_layer=x)
    x = InceptionBlock_C(prev_layer=x)
    x = InceptionBlock_C(prev_layer=x)

    x = GlobalAveragePooling2D()(x)

    x = Dense(units = 1536, activation='relu') (x)
    x = Dropout(rate = 0.8) (x)
    x = Dense(units = 1000, activation='relu')(x)

    model = Model(inputs = input_layer , outputs = x , name ='Inception-V4')

    return model

# %%
def conv2d_with_Batch(prev_layer , nbr_kernels , filter_size , strides = (1,1) , padding = 'valid'):
    x = Conv2D(filters = nbr_kernels, kernel_size = filter_size, strides=strides , padding=padding) (prev_layer)
    x = BatchNormalization()(x)
    x = Activation(activation = 'relu') (x)
    return x

# %%
def stemBlock(prev_layer):
    x = conv2d_with_Batch(prev_layer, nbr_kernels = 32, filter_size = (3,3), strides = (2,2))
    x = conv2d_with_Batch(x, nbr_kernels = 32, filter_size = (3,3))
    x = conv2d_with_Batch(x, nbr_kernels = 64, filter_size = (3,3))

    x_1 = conv2d_with_Batch(x, nbr_kernels = 96, filter_size = (3,3), strides = (2,2) )
    x_2 = MaxPool2D(pool_size=(3,3) , strides=(2,2) ) (x)

    x = concatenate([x_1 , x_2], axis = 3)

    x_1 = conv2d_with_Batch(x, nbr_kernels = 64, filter_size = (1,1))
    x_1 = conv2d_with_Batch(x_1, nbr_kernels = 64, filter_size = (1,7) , padding ='same')
    x_1 = conv2d_with_Batch(x_1, nbr_kernels = 64, filter_size = (7,1), padding ='same')
    x_1 = conv2d_with_Batch(x_1, nbr_kernels = 96, filter_size = (3,3))

    x_2 = conv2d_with_Batch(x, nbr_kernels = 96, filter_size = (1,1))
    x_2 = conv2d_with_Batch(x_2, nbr_kernels = 96, filter_size = (3,3))

    x = concatenate([x_1 , x_2], axis = 3)

    x_1 = conv2d_with_Batch(x, nbr_kernels = 192, filter_size = (3,3) , strides=2)
    x_2 = MaxPool2D(pool_size=(3,3) , strides=(2,2) ) (x)

    x = concatenate([x_1 , x_2], axis = 3)

    return x

# %%
def reduction_A_Block(prev_layer) :
    x_1 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 192, filter_size = (1,1))
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 224, filter_size = (3,3) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 256, filter_size = (3,3) , strides=(2,2))

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 384, filter_size = (3,3) , strides=(2,2))

    x_3 = MaxPool2D(pool_size=(3,3) , strides=(2,2))(prev_layer)

    x = concatenate([x_1 , x_2 , x_3], axis = 3)

    return x

# %%
def reduction_B_Block(prev_layer):
    x_1 = MaxPool2D(pool_size=(3,3) , strides=(2,2))(prev_layer)

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 192, filter_size = (1,1))
    x_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 192, filter_size = (3,3) , strides=(2,2) )

    x_3 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 256, filter_size = (1,1) )
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 256, filter_size = (1,7) , padding='same')
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 320, filter_size = (7,1) , padding='same')
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 320, filter_size = (3,3) , strides=(2,2))

    x = concatenate([x_1 , x_2 , x_3], axis = 3)
    return x

# %%
def InceptionBlock_A(prev_layer): #I'm Here

    x_1 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 64, filter_size = (1,1))
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 96, filter_size = (3,3) , strides=(1,1), padding='same' )
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 96, filter_size = (3,3) , strides=(1,1) , padding='same')

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 64, filter_size = (1,1))
    x_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 96, filter_size = (3,3) , padding='same')

    x_3 = AveragePooling2D(pool_size=(3,3) , strides=1 , padding='same')(prev_layer)
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 96, filter_size = (1,1) , padding='same')

    x_4 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 96, filter_size = (1,1))

    output = concatenate([x_1 , x_2 , x_3 , x_4], axis = 3)

    return output

# %%
def InceptionBlock_B(prev_layer):

    x_1 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 192, filter_size = (1,1))
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 192, filter_size = (1,7) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 224, filter_size = (7,1) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 224, filter_size = (1,7) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 256, filter_size = (7,1), padding='same')

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 192, filter_size = (1,1))
    x_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 224, filter_size = (1,7) , padding='same')
    x_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 256, filter_size = (1,7), padding='same')

    x_3 = AveragePooling2D(pool_size=(3,3) , strides=1 , padding='same')(prev_layer)
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 128, filter_size = (1,1))

    x_4 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 384, filter_size = (1,1))

    output = concatenate([x_1 , x_2 ,x_3, x_4], axis = 3)
    return output

# %%
def InceptionBlock_C(prev_layer):

    x_1 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 384, filter_size = (1,1))
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 448, filter_size = (1,3) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 512, filter_size = (3,1) , padding='same')
    x_1_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 256, filter_size = (1,3), padding='same')
    x_1_2 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 256, filter_size = (3,1), padding='same')
    x_1 = concatenate([x_1_1 , x_1_2], axis = 3)

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 384, filter_size = (1,1))
    x_2_1 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 256, filter_size = (1,3), padding='same')
    x_2_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 256, filter_size = (3,1), padding='same')
    x_2 = concatenate([x_2_1 , x_2_2], axis = 3)

    x_3 = AveragePooling2D(pool_size=(3,3),strides = 1 , padding='same')(prev_layer)
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 256, filter_size = 3  , padding='same')

    x_4 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 256, filter_size = (1,1))

    output = concatenate([x_1 , x_2 , x_3 , x_4], axis = 3)

    return output

# %%
model = InceptionV4()

# Custom Last Stage
x = model.output
predictions = tf.keras.layers.Dense(4, activation='softmax')(x)
model = tf.keras.Model(inputs=model.input, outputs=predictions)

# Compile
sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)
rmsprop = tf.keras.optimizers.RMSprop(learning_rate=0.001)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary
model.summary()
# Out:
# 2023-12-01 20:40:11.174573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10436 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:af:00.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 111, 111, 32)         896       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 111, 111, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 111, 111, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)         9248      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 109, 109, 32)         128       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 109, 109, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 107, 107, 64)         18496     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 107, 107, 64)         256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 107, 107, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 53, 53, 96)           55392     ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 53, 53, 96)           384       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 53, 53, 96)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 53, 53, 64)           0         ['activation_2[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 53, 53, 160)          0         ['activation_3[0][0]',
#                                                                      'max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 53, 53, 64)           10304     ['concatenate[0][0]']
#
#  batch_normalization_4 (Bat  (None, 53, 53, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 53, 53, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 53, 53, 64)           28736     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 53, 53, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 53, 53, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 53, 53, 64)           28736     ['activation_5[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 53, 53, 96)           15456     ['concatenate[0][0]']
#
#  batch_normalization_6 (Bat  (None, 53, 53, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 53, 53, 96)           384       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 53, 53, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 53, 53, 96)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 51, 51, 96)           55392     ['activation_6[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 51, 51, 96)           83040     ['activation_8[0][0]']
#
#  batch_normalization_7 (Bat  (None, 51, 51, 96)           384       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 51, 51, 96)           384       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 51, 51, 96)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 51, 51, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 51, 51, 192)          0         ['activation_7[0][0]',
#  )                                                                   'activation_9[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 25, 25, 192)          331968    ['concatenate_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 25, 25, 192)          768       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 25, 25, 192)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 192)          0         ['concatenate_1[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 25, 25, 384)          0         ['activation_10[0][0]',
#  )                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 25, 25, 64)           24640     ['concatenate_2[0][0]']
#
#  batch_normalization_11 (Ba  (None, 25, 25, 64)           256       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 25, 25, 96)           55392     ['activation_11[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 64)           24640     ['concatenate_2[0][0]']
#
#  batch_normalization_12 (Ba  (None, 25, 25, 96)           384       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 25, 25, 64)           256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  average_pooling2d (Average  (None, 25, 25, 384)          0         ['concatenate_2[0][0]']
#  Pooling2D)
#
#  conv2d_13 (Conv2D)          (None, 25, 25, 96)           83040     ['activation_12[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 25, 25, 96)           55392     ['activation_14[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 25, 25, 96)           36960     ['average_pooling2d[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 25, 25, 96)           36960     ['concatenate_2[0][0]']
#
#  batch_normalization_13 (Ba  (None, 25, 25, 96)           384       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 25, 25, 96)           384       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 25, 25, 96)           384       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 25, 25, 96)           384       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  concatenate_3 (Concatenate  (None, 25, 25, 384)          0         ['activation_13[0][0]',
#  )                                                                   'activation_15[0][0]',
#                                                                      'activation_16[0][0]',
#                                                                      'activation_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 25, 25, 64)           24640     ['concatenate_3[0][0]']
#
#  batch_normalization_18 (Ba  (None, 25, 25, 64)           256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 25, 25, 96)           55392     ['activation_18[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 25, 25, 64)           24640     ['concatenate_3[0][0]']
#
#  batch_normalization_19 (Ba  (None, 25, 25, 96)           384       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 25, 25, 64)           256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 25, 25, 384)          0         ['concatenate_3[0][0]']
#  gePooling2D)
#
#  conv2d_20 (Conv2D)          (None, 25, 25, 96)           83040     ['activation_19[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 25, 25, 96)           55392     ['activation_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 25, 25, 96)           36960     ['average_pooling2d_1[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 25, 25, 96)           36960     ['concatenate_3[0][0]']
#
#  batch_normalization_20 (Ba  (None, 25, 25, 96)           384       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 25, 25, 96)           384       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 25, 25, 96)           384       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 25, 25, 96)           384       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 25, 25, 384)          0         ['activation_20[0][0]',
#  )                                                                   'activation_22[0][0]',
#                                                                      'activation_23[0][0]',
#                                                                      'activation_24[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 25, 25, 64)           24640     ['concatenate_4[0][0]']
#
#  batch_normalization_25 (Ba  (None, 25, 25, 64)           256       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 25, 25, 96)           55392     ['activation_25[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 25, 25, 64)           24640     ['concatenate_4[0][0]']
#
#  batch_normalization_26 (Ba  (None, 25, 25, 96)           384       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 25, 25, 64)           256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 25, 25, 384)          0         ['concatenate_4[0][0]']
#  gePooling2D)
#
#  conv2d_27 (Conv2D)          (None, 25, 25, 96)           83040     ['activation_26[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 25, 25, 96)           55392     ['activation_28[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 25, 25, 96)           36960     ['average_pooling2d_2[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 25, 25, 96)           36960     ['concatenate_4[0][0]']
#
#  batch_normalization_27 (Ba  (None, 25, 25, 96)           384       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 25, 25, 96)           384       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 25, 25, 96)           384       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 25, 25, 96)           384       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_30 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  concatenate_5 (Concatenate  (None, 25, 25, 384)          0         ['activation_27[0][0]',
#  )                                                                   'activation_29[0][0]',
#                                                                      'activation_30[0][0]',
#                                                                      'activation_31[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 25, 25, 64)           24640     ['concatenate_5[0][0]']
#
#  batch_normalization_32 (Ba  (None, 25, 25, 64)           256       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 25, 25, 96)           55392     ['activation_32[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 25, 25, 64)           24640     ['concatenate_5[0][0]']
#
#  batch_normalization_33 (Ba  (None, 25, 25, 96)           384       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 25, 25, 64)           256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 25, 25, 384)          0         ['concatenate_5[0][0]']
#  gePooling2D)
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 96)           83040     ['activation_33[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 25, 25, 96)           55392     ['activation_35[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 25, 25, 96)           36960     ['average_pooling2d_3[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 25, 25, 96)           36960     ['concatenate_5[0][0]']
#
#  batch_normalization_34 (Ba  (None, 25, 25, 96)           384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 25, 25, 96)           384       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 25, 25, 96)           384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 25, 25, 96)           384       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, 25, 25, 384)          0         ['activation_34[0][0]',
#  )                                                                   'activation_36[0][0]',
#                                                                      'activation_37[0][0]',
#                                                                      'activation_38[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 25, 25, 192)          73920     ['concatenate_6[0][0]']
#
#  batch_normalization_39 (Ba  (None, 25, 25, 192)          768       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 25, 25, 192)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 25, 25, 224)          387296    ['activation_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, 25, 25, 224)          896       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 25, 25, 224)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 12, 12, 256)          516352    ['activation_40[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 12, 12, 384)          1327488   ['concatenate_6[0][0]']
#
#  batch_normalization_41 (Ba  (None, 12, 12, 256)          1024      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 12, 12, 384)          1536      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 12, 12, 256)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 12, 12, 384)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 384)          0         ['concatenate_6[0][0]']
#  g2D)
#
#  concatenate_7 (Concatenate  (None, 12, 12, 1024)         0         ['activation_41[0][0]',
#  )                                                                   'activation_42[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 12, 12, 192)          196800    ['concatenate_7[0][0]']
#
#  batch_normalization_43 (Ba  (None, 12, 12, 192)          768       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 12, 12, 192)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 12, 12, 192)          258240    ['activation_43[0][0]']
#
#  batch_normalization_44 (Ba  (None, 12, 12, 192)          768       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 12, 12, 192)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 12, 12, 224)          301280    ['activation_44[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 12, 12, 192)          196800    ['concatenate_7[0][0]']
#
#  batch_normalization_45 (Ba  (None, 12, 12, 224)          896       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 12, 12, 192)          768       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 12, 12, 224)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 12, 12, 192)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 12, 12, 224)          351456    ['activation_45[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 12, 12, 224)          301280    ['activation_48[0][0]']
#
#  batch_normalization_46 (Ba  (None, 12, 12, 224)          896       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 12, 12, 224)          896       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 12, 12, 224)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 12, 12, 224)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  average_pooling2d_4 (Avera  (None, 12, 12, 1024)         0         ['concatenate_7[0][0]']
#  gePooling2D)
#
#  conv2d_47 (Conv2D)          (None, 12, 12, 256)          401664    ['activation_46[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 12, 12, 256)          401664    ['activation_49[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 12, 12, 128)          131200    ['average_pooling2d_4[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 12, 12, 384)          393600    ['concatenate_7[0][0]']
#
#  batch_normalization_47 (Ba  (None, 12, 12, 256)          1024      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  batch_normalization_50 (Ba  (None, 12, 12, 256)          1024      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  batch_normalization_51 (Ba  (None, 12, 12, 128)          512       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 12, 12, 384)          1536      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 12, 12, 256)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  activation_50 (Activation)  (None, 12, 12, 256)          0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  activation_51 (Activation)  (None, 12, 12, 128)          0         ['batch_normalization_51[0][0]
#                                                                     ']
#
# ...
#
#  batch_normalization_132 (B  (None, 5, 5, 256)            1024      ['conv2d_132[0][0]']
#  atchNormalization)
#
#  batch_normalization_133 (B  (None, 5, 5, 256)            1024      ['conv2d_133[0][0]']
#  atchNormalization)
#
#  batch_normalization_135 (B  (None, 5, 5, 256)            1024      ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_136 (B  (None, 5, 5, 256)            1024      ['conv2d_136[0][0]']
#  atchNormalization)
#
#  conv2d_137 (Conv2D)         (None, 5, 5, 256)            3539200   ['average_pooling2d_12[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 5, 5, 256)            393472    ['concatenate_18[0][0]']
#
#  activation_132 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  activation_133 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  activation_135 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_136 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  batch_normalization_137 (B  (None, 5, 5, 256)            1024      ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_138 (B  (None, 5, 5, 256)            1024      ['conv2d_138[0][0]']
#  atchNormalization)
#
#  concatenate_19 (Concatenat  (None, 5, 5, 512)            0         ['activation_132[0][0]',
#  e)                                                                  'activation_133[0][0]']
#
#  concatenate_20 (Concatenat  (None, 5, 5, 512)            0         ['activation_135[0][0]',
#  e)                                                                  'activation_136[0][0]']
#
#  activation_137 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_138 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  concatenate_21 (Concatenat  (None, 5, 5, 1536)           0         ['concatenate_19[0][0]',
#  e)                                                                  'concatenate_20[0][0]',
#                                                                      'activation_137[0][0]',
#                                                                      'activation_138[0][0]']
#
#  conv2d_139 (Conv2D)         (None, 5, 5, 384)            590208    ['concatenate_21[0][0]']
#
#  batch_normalization_139 (B  (None, 5, 5, 384)            1536      ['conv2d_139[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_140 (Conv2D)         (None, 5, 5, 448)            516544    ['activation_139[0][0]']
#
#  batch_normalization_140 (B  (None, 5, 5, 448)            1792      ['conv2d_140[0][0]']
#  atchNormalization)
#
#  activation_140 (Activation  (None, 5, 5, 448)            0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_141 (Conv2D)         (None, 5, 5, 512)            688640    ['activation_140[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 5, 5, 384)            590208    ['concatenate_21[0][0]']
#
#  batch_normalization_141 (B  (None, 5, 5, 512)            2048      ['conv2d_141[0][0]']
#  atchNormalization)
#
#  batch_normalization_144 (B  (None, 5, 5, 384)            1536      ['conv2d_144[0][0]']
#  atchNormalization)
#
#  activation_141 (Activation  (None, 5, 5, 512)            0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  activation_144 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_144[0][0
#  )                                                                  ]']
#
#  conv2d_142 (Conv2D)         (None, 5, 5, 256)            393472    ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 5, 5, 256)            393472    ['activation_141[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 5, 5, 256)            295168    ['activation_144[0][0]']
#
#  conv2d_146 (Conv2D)         (None, 5, 5, 256)            295168    ['activation_144[0][0]']
#
#  average_pooling2d_13 (Aver  (None, 5, 5, 1536)           0         ['concatenate_21[0][0]']
#  agePooling2D)
#
#  batch_normalization_142 (B  (None, 5, 5, 256)            1024      ['conv2d_142[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 5, 5, 256)            1024      ['conv2d_143[0][0]']
#  atchNormalization)
#
#  batch_normalization_145 (B  (None, 5, 5, 256)            1024      ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_146 (B  (None, 5, 5, 256)            1024      ['conv2d_146[0][0]']
#  atchNormalization)
#
#  conv2d_147 (Conv2D)         (None, 5, 5, 256)            3539200   ['average_pooling2d_13[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 5, 5, 256)            393472    ['concatenate_21[0][0]']
#
#  activation_142 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  activation_143 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  activation_145 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_145[0][0
#  )                                                                  ]']
#
#  activation_146 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_146[0][0
#  )                                                                  ]']
#
#  batch_normalization_147 (B  (None, 5, 5, 256)            1024      ['conv2d_147[0][0]']
#  atchNormalization)
#
#  batch_normalization_148 (B  (None, 5, 5, 256)            1024      ['conv2d_148[0][0]']
#  atchNormalization)
#
#  concatenate_22 (Concatenat  (None, 5, 5, 512)            0         ['activation_142[0][0]',
#  e)                                                                  'activation_143[0][0]']
#
#  concatenate_23 (Concatenat  (None, 5, 5, 512)            0         ['activation_145[0][0]',
#  e)                                                                  'activation_146[0][0]']
#
#  activation_147 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_147[0][0
#  )                                                                  ]']
#
#  activation_148 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  concatenate_24 (Concatenat  (None, 5, 5, 1536)           0         ['concatenate_22[0][0]',
#  e)                                                                  'concatenate_23[0][0]',
#                                                                      'activation_147[0][0]',
#                                                                      'activation_148[0][0]']
#
#  global_average_pooling2d (  (None, 1536)                 0         ['concatenate_24[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1536)                 2360832   ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 1536)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1000)                 1537000   ['dropout[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    4004      ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 54609516 (208.32 MB)
# Trainable params: 54546284 (208.08 MB)
# Non-trainable params: 63232 (247.00 KB)
# __________________________________________________________________________________________________

# %%
filepath = 'models/PCD-test-aug-checkpoint.h5'

modelCheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath,
    monitor = 'val_accuracy',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False,
    mode = 'max',
    save_freq = 'epoch'
)
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.99):
      print("\nReached 99.9% accuracy so cancelling training!")
      self.model.stop_training = True
        
earlyStopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=20,
    verbose=1,
    mode='max'
)

# %%
callbacksList = [myCallback()]
history1 = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=200,
                    callbacks = callbacksList,
                    verbose=1)
# Out:
# Epoch 1/200
# 2023-12-01 18:39:55.282113: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2023-12-01 18:39:56.924798: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-12-01 18:39:57.199057: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-12-01 18:39:59.291034: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fad27913490 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-01 18:39:59.291067: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 8000, Compute Capability 7.5
# 2023-12-01 18:39:59.295907: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-01 18:39:59.447264: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 20/20 [==============================] - 121s 1s/step - loss: 1.6694 - accuracy: 0.3785 - val_loss: 90.4256 - val_accuracy: 0.1680
# Epoch 2/200
# 20/20 [==============================] - 9s 436ms/step - loss: 1.6663 - accuracy: 0.4649 - val_loss: 39.8784 - val_accuracy: 0.1680
# Epoch 3/200
# 20/20 [==============================] - 9s 436ms/step - loss: 1.6995 - accuracy: 0.3801 - val_loss: 639.4233 - val_accuracy: 0.1680
# Epoch 4/200
# 20/20 [==============================] - 8s 409ms/step - loss: 1.9363 - accuracy: 0.4698 - val_loss: 22.2018 - val_accuracy: 0.1680
# Epoch 5/200
# 20/20 [==============================] - 9s 436ms/step - loss: 1.4118 - accuracy: 0.4046 - val_loss: 1.6293 - val_accuracy: 0.3840
# Epoch 6/200
# 20/20 [==============================] - 9s 436ms/step - loss: 1.0840 - accuracy: 0.5057 - val_loss: 2.2288 - val_accuracy: 0.2880
# Epoch 7/200
# 20/20 [==============================] - 9s 435ms/step - loss: 1.0895 - accuracy: 0.4747 - val_loss: 2.0383 - val_accuracy: 0.1600
# Epoch 8/200
# 20/20 [==============================] - 9s 417ms/step - loss: 1.2528 - accuracy: 0.4666 - val_loss: 2.2284 - val_accuracy: 0.3840
# Epoch 9/200
# 20/20 [==============================] - 9s 438ms/step - loss: 1.1343 - accuracy: 0.5073 - val_loss: 1.8107 - val_accuracy: 0.3840
# Epoch 10/200
# 20/20 [==============================] - 9s 437ms/step - loss: 1.0599 - accuracy: 0.4715 - val_loss: 2.7032 - val_accuracy: 0.1600
# Epoch 11/200
# 20/20 [==============================] - 9s 414ms/step - loss: 1.0601 - accuracy: 0.4535 - val_loss: 2.7157 - val_accuracy: 0.3840
# Epoch 12/200
# 20/20 [==============================] - 9s 449ms/step - loss: 1.1058 - accuracy: 0.4927 - val_loss: 2.6267 - val_accuracy: 0.3840
# Epoch 13/200
# 20/20 [==============================] - 9s 436ms/step - loss: 1.0174 - accuracy: 0.4698 - val_loss: 2.4029 - val_accuracy: 0.3840
# Epoch 14/200
# 20/20 [==============================] - 9s 442ms/step - loss: 1.0887 - accuracy: 0.4747 - val_loss: 1.7870 - val_accuracy: 0.2880
# Epoch 15/200
# 20/20 [==============================] - 9s 419ms/step - loss: 1.1060 - accuracy: 0.4976 - val_loss: 2.0526 - val_accuracy: 0.3840
# Epoch 16/200
# 20/20 [==============================] - 9s 425ms/step - loss: 0.9807 - accuracy: 0.4927 - val_loss: 2.1254 - val_accuracy: 0.3840
# Epoch 17/200
# 20/20 [==============================] - 9s 439ms/step - loss: 0
200
# 20/20 [==============================] - 9s 438ms/step - loss: 0.9814 - accuracy: 0.4959 - val_loss: 0.9008 - val_accuracy: 0.5600
# Epoch 41/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.9945 - accuracy: 0.4894 - val_loss: 0.8684 - val_accuracy: 0.5680
# Epoch 42/200
# 20/20 [==============================] - 9s 415ms/step - loss: 0.9759 - accuracy: 0.5351 - val_loss: 0.9088 - val_accuracy: 0.4720
# Epoch 43/200
# 20/20 [==============================] - 9s 419ms/step - loss: 0.9736 - accuracy: 0.5057 - val_loss: 0.8474 - val_accuracy: 0.5760
# Epoch 44/200
# 20/20 [==============================] - 9s 435ms/step - loss: 0.9607 - accuracy: 0.5465 - val_loss: 1.0871 - val_accuracy: 0.3840
# Epoch 45/200
# 20/20 [==============================] - 9s 432ms/step - loss: 1.0354 - accuracy: 0.4959 - val_loss: 0.9223 - val_accuracy: 0.5440
# Epoch 46/200
# 20/20 [==============================] - 8s 406ms/step - loss: 0.9925 - accuracy: 0.5334 - val_loss: 0.8765 - val_accuracy: 0.5520
# Epoch 47/200
# 20/20 [==============================] - 9s 430ms/step - loss: 0.9349 - accuracy: 0.5334 - val_loss: 0.8371 - val_accuracy: 0.5600
# Epoch 48/200
# 20/20 [==============================] - 10s 472ms/step - loss: 0.8801 - accuracy: 0.5644 - val_loss: 0.9270 - val_accuracy: 0.4240
# Epoch 49/200
# 20/20 [==============================] - 9s 438ms/step - loss: 0.9418 - accuracy: 0.5693 - val_loss: 0.9239 - val_accuracy: 0.5200
# Epoch 50/200
# 20/20 [==============================] - 8s 405ms/step - loss: 0.9181 - accuracy: 0.5400 - val_loss: 0.8724 - val_accuracy: 0.5520
# Epoch 51/200
# 20/20 [==============================] - 9s 438ms/step - loss: 0.9802 - accuracy: 0.5416 - val_loss: 0.8664 - val_accuracy: 0.5360
# Epoch 52/200
# 20/20 [==============================] - 9s 437ms/step - loss: 1.0840 - accuracy: 0.5318 - val_loss: 1.7788 - val_accuracy: 0.1680
# Epoch 53/200
# 20/20 [==============================] - 9s 437ms/step - loss: 0.9503 - accuracy: 0.5334 - val_loss: 2.5297 - val_accuracy: 0.1680
# Epoch 54/200
# 20/20 [==============================] - 8s 401ms/step - loss: 1.0370 - accuracy: 0.4763 - val_loss: 2.5196 - val_accuracy: 0.1680
# Epoch 55/200
# 20/20 [==============================] - 10s 511ms/step - loss: 1.0689 - accuracy: 0.4829 - val_loss: 1.8055 - val_accuracy: 0.1920
# Epoch 56/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.9823 - accuracy: 0.5008 - val_loss: 1.7160 - val_accuracy: 0.2320
# Epoch 57/200
# 20/20 [==============================] - 9s 436ms/step - loss: 0.9571 - accuracy: 0.5188 - val_loss: 1.3671 - val_accuracy: 0.2640
# Epoch 58/200
# 20/20 [==============================] - 8s 398ms/step - loss: 1.0007 - accuracy: 0.5253 - val_loss: 0.8551 - val_accuracy: 0.5520
# Epoch 59/200
# 20/20 [==============================] - 10s 484ms/step - loss: 1.0409 - accuracy: 0.4927 - val_loss: 31.0507 - val_accuracy: 0.1680
# Epoch 60/200
# 20/20 [==============================] - 9s 449ms/step - loss: 0.9620 - accuracy: 0.5498 - val_loss: 20.1991 - val_accuracy: 0.1680
# Epoch 61/200
# 20/20 [==============================] - 17s 842ms/step - loss: 0.9151 - accuracy: 0.5612 - val_loss: 2.3651 - val_accuracy: 0.1680
# Epoch 62/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.9168 - accuracy: 0.5726 - val_loss: 1.1065 - val_accuracy: 0.4800
# Epoch 63/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0
200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.6388 - accuracy: 0.7553 - val_loss: 0.7026 - val_accuracy: 0.6640
# Epoch 180/200
# 20/20 [==============================] - 9s 438ms/step - loss: 0.6993 - accuracy: 0.7341 - val_loss: 1.2007 - val_accuracy: 0.5600
# Epoch 181/200
# 20/20 [==============================] - 9s 442ms/step - loss: 0.6869 - accuracy: 0.7015 - val_loss: 0.9229 - val_accuracy: 0.6080
# Epoch 182/200
# 20/20 [==============================] - 9s 450ms/step - loss: 0.6550 - accuracy: 0.7210 - val_loss: 1.9964 - val_accuracy: 0.3680
# Epoch 183/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.6490 - accuracy: 0.7390 - val_loss: 1.8804 - val_accuracy: 0.4240
# Epoch 184/200
# 20/20 [==============================] - 9s 437ms/step - loss: 0.6107 - accuracy: 0.7684 - val_loss: 0.7548 - val_accuracy: 0.6480
# Epoch 185/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.6212 - accuracy: 0.7651 - val_loss: 0.7438 - val_accuracy: 0.7040
# Epoch 186/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.7398 - accuracy: 0.6917 - val_loss: 1.4836 - val_accuracy: 0.4960
# Epoch 187/200
# 20/20 [==============================] - 9s 437ms/step - loss: 0.8019 - accuracy: 0.5954 - val_loss: 1.3712 - val_accuracy: 0.4480
# Epoch 188/200
# 20/20 [==============================] - 8s 393ms/step - loss: 0.7536 - accuracy: 0.6525 - val_loss: 1.7202 - val_accuracy: 0.4160
# Epoch 189/200
# 20/20 [==============================] - 9s 436ms/step - loss: 0.6944 - accuracy: 0.6998 - val_loss: 3.0877 - val_accuracy: 0.3840
# Epoch 190/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.6751 - accuracy: 0.6998 - val_loss: 3.8960 - val_accuracy: 0.3440
# Epoch 191/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.6471 - accuracy: 0.7537 - val_loss: 1.8995 - val_accuracy: 0.4080
# Epoch 192/200
# 20/20 [==============================] - 8s 391ms/step - loss: 0.6589 - accuracy: 0.7390 - val_loss: 1.6969 - val_accuracy: 0.4480
# Epoch 193/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.6795 - accuracy: 0.7080 - val_loss: 1.1819 - val_accuracy: 0.5920
# Epoch 194/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.6076 - accuracy: 0.7716 - val_loss: 0.7045 - val_accuracy: 0.6640
# Epoch 195/200
# 20/20 [==============================] - 9s 435ms/step - loss: 0.6036 - accuracy: 0.7635 - val_loss: 1.2790 - val_accuracy: 0.4960
# Epoch 196/200
# 20/20 [==============================] - 8s 403ms/step - loss: 0.6949 - accuracy: 0.7194 - val_loss: 0.7944 - val_accuracy: 0.6880
# Epoch 197/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.6771 - accuracy: 0.7259 - val_loss: 1.0190 - val_accuracy: 0.5840
# Epoch 198/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.6613 - accuracy: 0.7374 - val_loss: 0.8638 - val_accuracy: 0.6640
# Epoch 199/200
# 20/20 [==============================] - 9s 430ms/step - loss: 0.5751 - accuracy: 0.7716 - val_loss: 0.6862 - val_accuracy: 0.7200
# Epoch 200/200
# 20/20 [==============================] - 9s 438ms/step - loss: 0.6770 - accuracy: 0.7227 - val_loss: 0.6231 - val_accuracy: 0.7440

# %%
model.save('PCD-test-aug-callback.h5')
# Out:
# /home/dajuma/anaconda3/envs/myenv311/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
callbacksList = [modelCheckpoint]
history2 = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=200,
                    callbacks = callbacksList,
                    verbose=1)
# Out:
# Epoch 1/200
# 2023-12-01 19:16:09.819699: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2023-12-01 19:16:11.425223: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-12-01 19:16:11.747290: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-12-01 19:16:17.942134: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f7e5bc5ac60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-01 19:16:17.942216: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 8000, Compute Capability 7.5
# 2023-12-01 19:16:18.071254: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-01 19:16:18.885478: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 20/20 [==============================] - ETA: 0s - loss: 1.7091 - accuracy: 0.3719
# Epoch 1: val_accuracy improved from -inf to 0.16800, saving model to models/PCD-test-aug-checkpoint.h5
# /home/dajuma/anaconda3/envs/myenv311/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#
200
# 20/20 [==============================] - ETA: 0s - loss: 1.0922 - accuracy: 0.4992
# Epoch 16: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 9s 428ms/step - loss: 1.0922 - accuracy: 0.4992 - val_loss: 2.1040 - val_accuracy: 0.3840
# Epoch 17/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0005 - accuracy: 0.5106
# Epoch 17: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 9s 432ms/step - loss: 1.0005 - accuracy: 0.5106 - val_loss: 2.2806 - val_accuracy: 0.3840
# Epoch 18/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0706 - accuracy: 0.4878
# Epoch 18: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 8s 391ms/step - loss: 1.0706 - accuracy: 0.4878 - val_loss: 2.1942 - val_accuracy: 0.2880
# Epoch 19/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0250 - accuracy: 0.4682
# Epoch 19: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 9s 410ms/step - loss: 1.0250 - accuracy: 0.4682 - val_loss: 2.2974 - val_accuracy: 0.3840
# Epoch 20/200
# 20/20 [==============================] - ETA: 0s - loss: 1.1103 - accuracy: 0.5090
# Epoch 20: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 9s 460ms/step - loss: 1.1103 - accuracy: 0.5090 - val_loss: 2.2000 - val_accuracy: 0.3840
# Epoch 21/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0082 - accuracy: 0.4976
# Epoch 21: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 9s 431ms/step - loss: 1.0082 - accuracy: 0.4976 - val_loss: 2.1505 - val_accuracy: 0.3840
# Epoch 22/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0186 - accuracy: 0.5204
# Epoch 22: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 8s 402ms/step - loss: 1.0186 - accuracy: 0.5204 - val_loss: 2.2897 - val_accuracy: 0.3840
# Epoch 23/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0298 - accuracy: 0.4617
# Epoch 23: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 9s 417ms/step - loss: 1.0298 - accuracy: 0.4617 - val_loss: 2.0199 - val_accuracy: 0.2880
# Epoch 24/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9934 - accuracy: 0.5008
# Epoch 24: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 9s 433ms/step - loss: 0.9934 - accuracy: 0.5008 - val_loss: 2.2269 - val_accuracy: 0.3840
# Epoch 25/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9738 - accuracy: 0.5220
# Epoch 25: val_accuracy improved from 0.38400 to 0.46400, saving model to models/PCD-test-aug-checkpoint.h5
# 20/20 [==============================] - 12s 565ms/step - loss: 0.9738 - accuracy: 0.5220 - val_loss: 1.1205 - val_accuracy: 0.4640
# Epoch 26/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9779 - accuracy: 0.5139
# Epoch 26: val_accuracy improved from 0.46400 to 0.54400, saving model to models/PCD-test-aug-checkpoint.h5
# 20/20 [==============================] - 10s 503ms/step - loss: 0.9779 - accuracy: 0.5139 - val_loss: 1.0176 - val_accuracy: 0.5440
# Epoch 27/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0489 - accuracy: 0.4682
# Epoch 27: val_accuracy did not improve from 0.54400
# 20/20 [==============================] - 9s 430ms/step - loss: 1.0489 - accuracy: 0.4682 - val_loss: 1.0612 - val_accuracy: 0.4880
# Epoch 28/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9766 - accuracy: 0.5220
# Epoch 28: val_accuracy improved from 0.54400 to 0.55200, saving model to models/PCD-test-aug-checkpoint.h5
# 20/20 [==============================] - 11s 540ms/step - loss: 0.9766 - accuracy: 0.5220 - val_loss: 1.0499 - val_accuracy: 0.5520
# Epoch 29/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0215 - accuracy: 0.5171
# Epoch 29: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 8s 383ms/step - loss: 1.0215 - accuracy: 0.5171 - val_loss: 0.9318 - val_accuracy: 0.5520
# Epoch 30/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0010 - accuracy: 0.4943
# Epoch 30: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 460ms/step - loss: 1.0010 - accuracy: 0.4943 - val_loss: 1.0216 - val_accuracy: 0.5520
# Epoch 31/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0044 - accuracy: 0.5139
# Epoch 31: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 435ms/step - loss: 1.0044 - accuracy: 0.5139 - val_loss: 0.9346 - val_accuracy: 0.5520
# Epoch 32/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9447 - accuracy: 0.5318
# Epoch 32: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 435ms/step - loss: 0.9447 - accuracy: 0.5318 - val_loss: 0.9149 - val_accuracy: 0.5520
# Epoch 33/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0516 - accuracy: 0.5188
# Epoch 33: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 8s 391ms/step - loss: 1.0516 - accuracy: 0.5188 - val_loss: 0.9377 - val_accuracy: 0.5520
# Epoch 34/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9604 - accuracy: 0.5302
# Epoch 34: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.9604 - accuracy: 0.5302 - val_loss: 0.9174 - val_accuracy: 0.5520
# Epoch 35/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9885 - accuracy: 0.5188
# Epoch 35: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 431ms/step - loss: 0.9885 - accuracy: 0.5188 - val_loss: 0.9266 - val_accuracy: 0.5520
# Epoch 36/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9719 - accuracy: 0.5024
# Epoch 36: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 430ms/step - loss: 0.9719 - accuracy: 0.5024 - val_loss: 0.9107 - val_accuracy: 0.5520
# Epoch 37/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9767 - accuracy: 0.4861
# Epoch 37: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 423ms/step - loss: 0.9767 - accuracy: 0.4861 - val_loss: 0.9375 - val_accuracy: 0.4560
# Epoch 38/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9728 - accuracy: 0.5090
# Epoch 38: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 431ms/step - loss: 0.9728 - accuracy: 0.5090 - val_loss: 0.9222 - val_accuracy: 0.5520
# Epoch 39/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9727 - accuracy: 0.5188
# Epoch 39: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.9727 - accuracy: 0.5188 - val_loss: 1.3938 - val_accuracy: 0.1680
# Epoch 40/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9467 - accuracy: 0.5334
# Epoch 40: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.9467 - accuracy: 0.5334 - val_loss: 1.0120 - val_accuracy: 0.5280
# Epoch 41/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9740 - accuracy: 0.5008
# Epoch 41: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 442ms/step - loss: 0.9740 - accuracy: 0.5008 - val_loss: 0.8937 - val_accuracy: 0.5520
# Epoch 42/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9677 - accuracy: 0.5220
# Epoch 42: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.9677 - accuracy: 0.5220 - val_loss: 0.8800 - val_accuracy: 0.5520
# Epoch 43/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0617 - accuracy: 0.5073
# Epoch 43: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 434ms/step - loss: 1.0617 - accuracy: 0.5073 - val_loss: 0.8955 - val_accuracy: 0.5520
# Epoch 44/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9458 - accuracy: 0.5351
# Epoch 44: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 420ms/step - loss: 0.9458 - accuracy: 0.5351 - val_loss: 1.2426 - val_accuracy: 0.3760
# Epoch 45/200
# 20/20 [==============================] - ETA: 0s - loss: 1.1022 - accuracy: 0.4927
# Epoch 45: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 444ms/step - loss: 1.1022 - accuracy: 0.4927 - val_loss: 1.0073 - val_accuracy: 0.5520
# Epoch 46/200
# 20/20 [==============================] - ETA: 0s - loss: 1.0143 - accuracy: 0.5155
# Epoch 46: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 431ms/step - loss: 1.0143 - accuracy: 0.5155 - val_loss: 0.9285 - val_accuracy: 0.5520
# Epoch 47/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9991 - accuracy: 0.4829
# Epoch 47: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.9991 - accuracy: 0.4829 - val_loss: 0.8926 - val_accuracy: 0.5520
# Epoch 48/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9710 - accuracy: 0.5155
# Epoch 48: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 404ms/step - loss: 0.9710 - accuracy: 0.5155 - val_loss: 0.9107 - val_accuracy: 0.4560
# Epoch 49/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9711 - accuracy: 0.5008
# Epoch 49: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 439ms/step - loss: 0.9711 - accuracy: 0.5008 - val_loss: 0.9052 - val_accuracy: 0.5520
# Epoch 50/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9529 - accuracy: 0.5237
# Epoch 50: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.9529 - accuracy: 0.5237 - val_loss: 0.8947 - val_accuracy: 0.5520
# Epoch 51/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9592 - accuracy: 0.5155
# Epoch 51: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 9s 435ms/step - loss: 0.9592 - accuracy: 0.5155 - val_loss: 0.8966 - val_accuracy: 0.4560
# Epoch 52/200
# 20/20 [==============================] - ETA: 0s - loss: 0.9386 - accuracy: 0.4927
# Epoch 52: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 8s
200
# 20/20 [==============================] - ETA: 0s - loss: 0.8367 - accuracy: 0.6003
# Epoch 126: val_accuracy did not improve from 0.56000
# 20/20 [==============================] - 9s 431ms/step - loss: 0.8367 - accuracy: 0.6003 - val_loss: 1.0010 - val_accuracy: 0.5520
# Epoch 127/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8451 - accuracy: 0.5987
# Epoch 127: val_accuracy improved from 0.56000 to 0.59200, saving model to models/PCD-test-aug-checkpoint.h5
# 20/20 [==============================] - 11s 555ms/step - loss: 0.8451 - accuracy: 0.5987 - val_loss: 0.7827 - val_accuracy: 0.5920
# Epoch 128/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8442 - accuracy: 0.6101
# Epoch 128: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 13s 638ms/step - loss: 0.8442 - accuracy: 0.6101 - val_loss: 0.8466 - val_accuracy: 0.5520
# Epoch 129/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8057 - accuracy: 0.6199
# Epoch 129: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.8057 - accuracy: 0.6199 - val_loss: 1.0284 - val_accuracy: 0.4560
# Epoch 130/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8436 - accuracy: 0.6150
# Epoch 130: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 429ms/step - loss: 0.8436 - accuracy: 0.6150 - val_loss: 0.8832 - val_accuracy: 0.4880
# Epoch 131/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8028 - accuracy: 0.6183
# Epoch 131: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 8s 393ms/step - loss: 0.8028 - accuracy: 0.6183 - val_loss: 0.7672 - val_accuracy: 0.5920
# Epoch 132/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7689 - accuracy: 0.6166
# Epoch 132: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.7689 - accuracy: 0.6166 - val_loss: 1.0647 - val_accuracy: 0.4880
# Epoch 133/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7481 - accuracy: 0.6330
# Epoch 133: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 429ms/step - loss: 0.7481 - accuracy: 0.6330 - val_loss: 1.2062 - val_accuracy: 0.4880
# Epoch 134/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7947 - accuracy: 0.6264
# Epoch 134: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 435ms/step - loss: 0.7947 - accuracy: 0.6264 - val_loss: 0.9955 - val_accuracy: 0.4800
# Epoch 135/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8103 - accuracy: 0.6020
# Epoch 135: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 423ms/step - loss: 0.8103 - accuracy: 0.6020 - val_loss: 0.8400 - val_accuracy: 0.5360
# Epoch 136/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8029 - accuracy: 0.5922
# Epoch 136: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 462ms/step - loss: 0.8029 - accuracy: 0.5922 - val_loss: 0.9402 - val_accuracy: 0.5120
# Epoch 137/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7983 - accuracy: 0.6215
# Epoch 137: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.7983 - accuracy: 0.6215 - val_loss: 1.4006 - val_accuracy: 0.3920
# Epoch 138/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7600 - accuracy: 0.6330
# Epoch 138: val_accuracy did not improve from 0.59200
# 20/20 [==============================] - 9s 431ms/step - loss: 0.7600 - accuracy: 0.6330 - val_loss: 1.0793 - val_accuracy: 0.4880
# Epoch 139/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7989 - accuracy: 0.6313
# Epoch 139: val_accuracy improved from 0.59200 to 0.63200, saving model to models/PCD-test-aug-checkpoint.h5
# 20/20 [==============================] - 11s 547ms/step - loss: 0.7989 - accuracy: 0.6313 - val_loss: 0.6713 - val_accuracy: 0.6320
# Epoch 140/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7875 - accuracy: 0.6232
# Epoch 140: val_accuracy did not improve from 0.63200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.7875 - accuracy: 0.6232 - val_loss: 0.7913 - val_accuracy: 0.5440
# Epoch 141/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8258 - accuracy: 0.5856
# Epoch 141: val_accuracy did not improve from 0.63200
# 20/20 [==============================] - 9s 431ms/step - loss: 0.8258 - accuracy: 0.5856 - val_loss: 1.1885 - val_accuracy: 0.4960
# Epoch 142/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8074 - accuracy: 0.6378
# Epoch 142: val_accuracy did not improve from 0.63200
# 20/20 [==============================] - 8s 390ms/step - loss: 0.8074 - accuracy: 0.6378 - val_loss: 0.9171 - val_accuracy: 0.4800
# Epoch 143/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7557 - accuracy: 0.6411
# Epoch 143: val_accuracy improved from 0.63200 to 0.71200, saving model to models/PCD-test-aug-checkpoint.h5
# 20/20 [==============================] -
200
# 20/20 [==============================] - ETA: 0s - loss: 0.6726 - accuracy: 0.6917
# Epoch 199: val_accuracy did not improve from 0.76000
# 20/20 [==============================] - 8s 391ms/step - loss: 0.6726 - accuracy: 0.6917 - val_loss: 0.7856 - val_accuracy: 0.5680
# Epoch 200/200
# 20/20 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.6656
# Epoch 200: val_accuracy did not improve from 0.76000
# 20/20 [==============================] - 9s 462ms/step - loss: 0.6849 - accuracy: 0.6656 - val_loss: 0.9100 - val_accuracy: 0.5280

# %%
callbacksList = [earlyStopping]
history3 = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=200,
                    callbacks = callbacksList,
                    verbose=1)
model.save('PCD-test-aug-early-stopping.h5')
# Out:
# Epoch 1/200
# 2023-12-01 20:41:07.916660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2023-12-01 20:41:08.664996: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-12-01 20:41:08.898104: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-12-01 20:41:10.673340: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd1662c03b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-01 20:41:10.673380: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 8000, Compute Capability 7.5
# 2023-12-01 20:41:10.678239: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-01 20:41:10.831071: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 20/20 [==============================] - 119s 1s/step - loss: 2.0522 - accuracy: 0.4144 - val_loss: 1.5546 - val_accuracy: 0.1600
# Epoch 2/200
# 20/20 [==============================] - 9s 433ms/step - loss: 1.3339 - accuracy: 0.4421 - val_loss: 94.0044 - val_accuracy: 0.1680
# Epoch 3/200
# 20/20 [==============================] - 8s 404ms/step - loss: 1.8346 - accuracy: 0.4600 - val_loss: 384.3224 - val_accuracy: 0.1680
# Epoch 4/200
# 20/20 [==============================] - 9s 418ms/step - loss: 1.3715 - accuracy: 0.4144 - val_loss: 407.1097 - val_accuracy: 0.1680
# Epoch 5/200
# 20/20 [==============================] - 9s 430ms/step - loss: 1.6218 - accuracy: 0.4356 - val_loss: 581.8531 - val_accuracy: 0.1680
# Epoch 6/200
# 20/20 [==============================] - 9s 432ms/step - loss: 1.3889 - accuracy: 0.4715 - val_loss: 16.6023 - val_accuracy: 0.1680
# Epoch 7/200
# 20/20 [==============================] - 9s 424ms/step - loss: 1.3802 - accuracy: 0.4731 - val_loss: 1.8116 - val_accuracy: 0.3840
# Epoch 8/200
# 20/20 [==============================] - 8s 432ms/step - loss: 1.3549 - accuracy: 0.4502 - val_loss: 2.2835 - val_accuracy: 0.1600
# Epoch 9/200
# 20/20 [==============================] - 9s 433ms/step - loss: 1.1231 - accuracy: 0.4666 - val_loss: 2.3271 - val_accuracy: 0.3840
# Epoch 10/200
# 20/20 [==============================] - 9s 438ms/step - loss: 1.0949 - accuracy: 0.5024 - val_loss: 2.1804 - val_accuracy: 0.3840
# Epoch 11/200
# 20/20 [==============================] - 9s 432ms/step - loss: 1.0467 - accuracy: 0.4927 - val_loss: 2.3444 - val_accuracy: 0.3840
# Epoch 12/200
# 20/20 [==============================] - 9s 414ms/step - loss: 1.0918 - accuracy: 0.4715 - val_loss: 1.9964 - val_accuracy: 0.3840
# Epoch 13/200
# 20/20 [==============================] - 9s 457ms/step - loss: 1.0511 - accuracy: 0.5024 - val_loss: 2.1608 - val_accuracy: 0.3840
# Epoch 14/200
# 20/20 [==============================] - 9s 433ms/step - loss: 1.0358 - accuracy: 0.5024 - val_loss: 2.3776 - val_accuracy: 0.3840
# Epoch 15/200
# 20/20 [==============================] - 9s 430ms/step - loss: 1.1386 - accuracy: 0.4812 - val_loss: 2.3665 - val_accuracy: 0.3840
# Epoch 16/200
# 20/20 [==============================] - 8s 408ms/step - loss: 1.0453 - accuracy: 0.4959 - val_loss: 2.1555 - val_accuracy: 0.2880
# Epoch 17/200
# 20/20 [==============================] - 9s 433ms/step - loss: 1.0610 - accuracy: 0.4959 - val_loss: 2.4861 - val_accuracy: 0.3840
# Epoch 18/200
# 20/20 [==============================] - 9s 435ms/step - loss: 1.0298 - accuracy: 0.5155 - val_loss: 1.7618 - val_accuracy: 0.2880
# Epoch 19/200
# 20/20 [==============================] - 12s 594ms/step - loss: 1.0249 - accuracy: 0.4698 - val_loss: 1.6497 - val_accuracy: 0.3760
# Epoch 20/200
# 20/20 [==============================] - 9s 431ms/step - loss: 0.9965 - accuracy: 0.4894 - val_loss: 1.4004 - val_accuracy: 0.3840
# Epoch 21/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.9847 - accuracy: 0.5057 - val_loss: 1.8276 - val_accuracy: 0.4000
# Epoch 22/200
# 20/20 [==============================] - 12s 566ms/step - loss: 1.0078 - accuracy: 0.5008 - val_loss: 1.8861 - val_accuracy: 0.3200
# Epoch 23/200
# 20/20 [==============================] - 8s 402ms/step - loss: 0.9502 - accuracy: 0.5530 - val_loss: 1.5902 - val_accuracy: 0.3920
# Epoch 24/200
# 20/20 [==============================] - 9s 431ms/step - loss: 0.9291 - accuracy: 0.5416 - val_loss: 1.0625 - val_accuracy: 0.4400
# Epoch 25/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.9713 - accuracy: 0.5269 - val_loss: 1.0784 - val_accuracy: 0.4160
# Epoch 26/200
# 20/20 [==============================] - 9s 454ms/step - loss: 1.0011 - accuracy: 0.5400 - val_loss: 5.0904 - val_accuracy: 0.4720
# Epoch 27/200
# 20/20 [==============================] - 8s 404ms/step - loss: 0.9956 - accuracy: 0.4812 - val_loss: 0.8766 - val_accuracy: 0.5520
# Epoch 28/200
# 20/20 [==============================] - 9s 432ms/step - loss: 1.0020 - accuracy: 0.5171 - val_loss: 0.9433 - val_accuracy: 0.5520
# Epoch 29/200
# 20/20 [==============================] - 9s 431ms/step - loss: 0.9955 - accuracy: 0.4894 - val_loss: 0.9559 - val_accuracy: 0.4560
# Epoch 30/200
# 20/20 [==============================] - 10s 422ms/step - loss: 1.0496 - accuracy: 0.4812 - val_loss: 0.9186 - val_accuracy: 0.4560
# Epoch 31/200
# 20/20 [==============================] - 8s 414ms/step - loss: 0.9967 - accuracy: 0.5090 - val_loss: 0.9035 - val_accuracy: 0.5520
# Epoch 32/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.9448 - accuracy: 0.5400 - val_loss: 0.8828 - val_accuracy: 0.5520
# Epoch 33/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.9483 - accuracy: 0.5612 - val_loss: 0.8956 - val_accuracy: 0.4640
# Epoch 34/200
# 20/20 [==============================] - 9s 422ms/step - loss: 0.9357 - accuracy: 0.5057 - val_loss: 0.8997 - val_accuracy: 0.5520
# Epoch 35/200
# 20/20 [==============================] - 8s 414ms/step - loss: 0.9276 - accuracy: 0.5351 - val_loss: 0.8610 - val_accuracy: 0.5600
# Epoch 36/200
# 20/20 [==============================] - 13s 623ms/step - loss: 0.9435 - accuracy: 0.5775 - val_loss: 1.0171 - val_accuracy: 0.4560
# Epoch 37/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.8990 - accuracy: 0.5873 - val_loss: 0.8179 - val_accuracy: 0.5840
# Epoch 38/200
# 20/20 [==============================] - 8s 376ms/step - loss: 0.8875 - accuracy: 0.5595 - val_loss: 0.8189 - val_accuracy: 0.5840
# Epoch 39/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.8739 - accuracy: 0.6101 - val_loss: 1.1080 - val_accuracy: 0.4640
# Epoch 40/200
# 20/20 [==============================] - 10s 477ms/step - loss: 1.0128 - accuracy: 0.5204 - val_loss: 0.8725 - val_accuracy: 0.4800
# Epoch 41/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.8683 - accuracy: 0.5971 - val_loss: 0.8192 - val_accuracy: 0.5520
# Epoch 42/200
# 20/20 [==============================] - 8s 404ms/step - loss: 0.8560 - accuracy: 0.5808 - val_loss: 0.9963 - val_accuracy: 0.4240
# Epoch 43/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.8131 - accuracy: 0.6101 - val_loss: 0.8164 - val_accuracy: 0.5920
# Epoch 44/200
# 20/20 [==============================] - 12s 433ms/step - loss: 0.9140 - accuracy: 0.5759 - val_loss: 0.8473 - val_accuracy: 0.5440
# Epoch 45/200
# 20/20 [==============================] - 8s 384ms/step - loss: 0.8918 - accuracy: 0.5726 - val_loss: 0.8939 - val_accuracy: 0.4560
# Epoch 46/200
# 20/20 [==============================] - 9s 436ms/step - loss: 0.8811 - accuracy: 0.6052 - val_loss: 0.8472 - val_accuracy: 0.4800
# Epoch 47/200
# 20/20 [==============================] - 12s 576ms/step - loss: 0.9312 - accuracy: 0.5856 - val_loss: 0.7985 - val_accuracy: 0.5440
# Epoch 48/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.8722 - accuracy: 0.5922 - val_loss: 1.5939 - val_accuracy: 0.2720
# Epoch 49/200
# 20/20 [==============================] - 8s 394ms/step - loss: 0.8868 - accuracy: 0.5971 - val_loss: 1.4702 - val_accuracy: 0.3120
# Epoch 50/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.9000 - accuracy: 0.5840 - val_loss: 2.2274 - val_accuracy: 0.2960
# Epoch 51/200
# 20/20 [==============================] - 12s 565ms/step - loss: 0.8084 - accuracy: 0.6003 - val_loss: 1.0838 - val_accuracy: 0.4320
# Epoch 52/200
# 20/20 [==============================] - 8s 388ms/step - loss: 0.8535 - accuracy: 0.6085 - val_loss: 0.8975 - val_accuracy: 0.6160
# Epoch 53/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.8324 - accuracy: 0.6134 - val_loss: 0.7872 - val_accuracy: 0.5680
# Epoch 54/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.7803 - accuracy: 0.6069 - val_loss: 0.9735 - val_accuracy: 0.5200
# Epoch 55/200
# 20/20 [==============================] - 9s 434ms/step - loss: 0.8179 - accuracy: 0.6020 - val_loss: 0.7011 - val_accuracy: 0.6160
# Epoch 56/200
# 20/20 [==============================] - 10s 384ms/step - loss: 0.8728 - accuracy: 0.5905 - val_loss: 0.7077 - val_accuracy: 0.5920
# Epoch 57/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.8474 - accuracy: 0.5987 - val_loss: 1.0298 - val_accuracy: 0.4960
# Epoch 58/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.8535 - accuracy: 0.6036 - val_loss: 1.2521 - val_accuracy: 0.3600
# Epoch 59/200
# 20/20 [==============================] - 9s 435ms/step - loss: 0.9717 - accuracy: 0.5791 - val_loss: 1.0128 - val_accuracy: 0.4080
# Epoch 60/200
# 20/20 [==============================] - 10s 485ms/step - loss: 0.8834 - accuracy: 0.5824 - val_loss: 0.8298 - val_accuracy: 0.4960
# Epoch 61/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.8325 - accuracy: 0.6069 - val_loss: 0.7185 - val_accuracy: 0.5520
# Epoch 62/200
# 20/20 [==============================] - 9s 431ms/step - loss: 0.8598 - accuracy: 0.6101 - val_loss: 0.7628 - val_accuracy: 0.5520
# Epoch 63/200
# 20/20 [==============================] - 11s 544ms/step - loss: 0.8259 - accuracy: 0.6493 - val_loss: 0.7422 - val_accuracy: 0.5840
# Epoch 64/200
# 20/20 [==============================] - 9s 424ms/step - loss: 0.8643 - accuracy: 0.6183 - val_loss: 0.9357 - val_accuracy: 0.5280
# Epoch 65/200
# 20/20 [==============================] - 9s 432ms/step - loss: 0.8309 - accuracy: 0.5775 - val_loss: 0.9927 - val_accuracy: 0.4400
# Epoch 66/200
# 20/20 [==============================] - 9s 435ms/step - loss: 0.8791 - accuracy: 0.5873 - val_loss: 0.9167 - val_accuracy: 0.4960
# Epoch 67/200
# 20/20 [==============================] - 9s 407ms/step - loss: 0.8425 - accuracy: 0.6101 - val_loss: 0.8626 - val_accuracy: 0.5280
# Epoch 68/200
# 20/20 [==============================] - 9s 438ms/step - loss: 0.8351 - accuracy: 0.6134 - val_loss: 0.7751 - val_accuracy: 0.5360
# Epoch 69/200
# 20/20 [==============================] - 10s 456ms/step - loss: 0.7704 - accuracy: 0.6493 - val_loss: 0.7666 - val_accuracy: 0.5600
# Epoch 70/200
# 20/20 [==============================] - 12s 567ms/step - loss: 0.8128 - accuracy: 0.6346 - val_loss: 1.0619 - val_accuracy: 0.4640
# Epoch 71/200
# 20/20 [==============================] - 8s 401ms/step - loss: 0.8611 - accuracy: 0.6069 - val_loss: 1.0272 - val_accuracy: 0.4800
# Epoch 72/200
# 20/20 [==============================] - 9s 433ms/step - loss: 0.8656 - accuracy: 0.6069 - val_loss: 0.7906 - val_accuracy: 0.5520
# Epoch 72: early stopping
# /home/dajuma/anaconda3/envs/myenv311/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
acc=history1.history['accuracy']
val_acc=history1.history['val_accuracy']
loss=history1.history['loss']
val_loss=history1.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.show()
print("")

plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()

# %%
acc=history2.history['accuracy']
val_acc=history2.history['val_accuracy']
loss=history2.history['loss']
val_loss=history2.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.show()
print("")

plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()

# %%
acc=history3.history['accuracy']
val_acc=history3.history['val_accuracy']
loss=history3.history['loss']
val_loss=history3.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.show()
print("")

plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()

# %%
load_model = tf.keras.models.load_model('models/PCD-test-no-aug-no-patience.h5')
# Out:
# 2023-11-13 12:14:34.751521: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-11-13 12:14:34.751554: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-11-13 12:14:34.751864: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
x, y = test_generator.next()
print("x: ",len(x)," y: ",len(y))
# Out:
# x:  190  y:  190

# %%
pred = load_model.predict(x)

y_test = []
for i in pred:
    y_test.append(np.argmax(i))

y_pred = []
for i in y:
    y_pred.append(np.argmax(i))
# Out:
# 6/6 [==============================] - 5s 504ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

sns.set(rc = {'figure.figsize':(15,10)})
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')

ax.set_title('Seaborn Confusion Matrix\n');
ax.set_xlabel('Result Predict(y_test)')
ax.set_ylabel('Actual Values(y_pred) ');

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66        73
#            1       0.97      0.59      0.73        51
#            2       0.94      1.00      0.97        31
#            3       0.52      0.80      0.63        35
#
#     accuracy                           0.72       190
#    macro avg       0.77      0.76      0.75       190
# weighted avg       0.76      0.72      0.72       190

# %%
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

precision2 = precision_score(y_test, y_pred, average='micro')
recall2 = recall_score(y_test, y_pred, average='micro')
f1score2 = f1_score(y_test, y_pred, average='micro')

print(f"Precision = {precision2}")
print(f"Recall = {recall2}")
print(f"F1 Score = {f1score2}")
# Out:
# Precision = 0.7210526315789474
# Recall = 0.7210526315789474
# F1 Score = 0.7210526315789474
