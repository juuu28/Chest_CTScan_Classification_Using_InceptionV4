# %%
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt
import os
from tensorflow import keras
from keras.models import Model
from tensorflow.keras import layers
from keras.layers import concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from keras.layers import Conv2D , MaxPool2D , Input , GlobalAveragePooling2D ,AveragePooling2D, Dense , Dropout ,Activation , BatchNormalization
# Out:
# 2023-11-12 16:26:52.250968: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-12 16:26:52.379219: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-12 16:26:52.414043: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-12 16:26:53.033877: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-11-12 16:26:53.033946: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-11-12 16:26:53.033953: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
def train_val_generators(TRAINING_DIR, TEST_DIR):

  train_datagen = ImageDataGenerator(rescale=1./255)
  train_generator = train_datagen.flow_from_directory(directory=TRAINING_DIR,
                                                      batch_size=32,
                                                      class_mode='categorical',
                                                      target_size=(224, 224))
  validation_datagen = ImageDataGenerator(rescale=1/255)
  

  test_datagen = ImageDataGenerator(rescale=1/255, 
                                   validation_split=0.4)
  validation_generator = test_datagen.flow_from_directory(directory=TEST_DIR,
                                                                batch_size=32,
                                                                class_mode='categorical',
                                                                target_size=(224, 224),
                                                                subset='validation')
  test_generator = test_datagen.flow_from_directory(directory=TEST_DIR,
                                                                batch_size=256,
                                                                class_mode='categorical',
                                                                target_size=(224, 224), 
                                                                subset='training')

  return train_generator, validation_generator, test_generator

# %%
train_generator, validation_generator, test_generator = train_val_generators('Chest_CTScan_dataset-main/train', 'Chest_CTScan_dataset-main/test')
# Out:
# Found 613 images belonging to 4 classes.
# Found 125 images belonging to 4 classes.
# Found 190 images belonging to 4 classes.

# %%
# Menghitung jumlah data per kelas
num_classes = len(train_generator.class_indices)
class_counts = np.zeros(num_classes)

for i in range(len(train_generator)):
    batch_labels = np.argmax(train_generator[i][1], axis=1)
    class_counts += np.bincount(batch_labels, minlength=num_classes)

# Mendapatkan nama kelas
class_names = list(train_generator.class_indices.keys())

plt.bar(classes, class_counts)
plt.title('Distribusi Kelas Gambar')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.xticks(rotation=90)
plt.show()

# %%
def InceptionV4():

    input_layer = Input(shape=(224 , 224 , 3))

    x = stemBlock(prev_layer=input_layer)

    x = InceptionBlock_A(prev_layer=x)
    x = InceptionBlock_A(prev_layer=x)
    x = InceptionBlock_A(prev_layer=x)
    x = InceptionBlock_A(prev_layer=x)

    x = reduction_A_Block(prev_layer=x)

    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)
    x = InceptionBlock_B(prev_layer=x)

    x = reduction_B_Block(prev_layer= x)

    x = InceptionBlock_C(prev_layer=x)
    x = InceptionBlock_C(prev_layer=x)
    x = InceptionBlock_C(prev_layer=x)

    x = GlobalAveragePooling2D()(x)

    x = Dense(units = 1536, activation='relu') (x)
    x = Dropout(rate = 0.8) (x)
    x = Dense(units = 1000, activation='relu')(x)

    model = Model(inputs = input_layer , outputs = x , name ='Inception-V4')

    return model

# %%
def conv2d_with_Batch(prev_layer , nbr_kernels , filter_size , strides = (1,1) , padding = 'valid'):
    x = Conv2D(filters = nbr_kernels, kernel_size = filter_size, strides=strides , padding=padding) (prev_layer)
    x = BatchNormalization()(x)
    x = Activation(activation = 'relu') (x)
    return x

# %%
def stemBlock(prev_layer):
    x = conv2d_with_Batch(prev_layer, nbr_kernels = 32, filter_size = (3,3), strides = (2,2))
    x = conv2d_with_Batch(x, nbr_kernels = 32, filter_size = (3,3))
    x = conv2d_with_Batch(x, nbr_kernels = 64, filter_size = (3,3))

    x_1 = conv2d_with_Batch(x, nbr_kernels = 96, filter_size = (3,3), strides = (2,2) )
    x_2 = MaxPool2D(pool_size=(3,3) , strides=(2,2) ) (x)

    x = concatenate([x_1 , x_2], axis = 3)

    x_1 = conv2d_with_Batch(x, nbr_kernels = 64, filter_size = (1,1))
    x_1 = conv2d_with_Batch(x_1, nbr_kernels = 64, filter_size = (1,7) , padding ='same')
    x_1 = conv2d_with_Batch(x_1, nbr_kernels = 64, filter_size = (7,1), padding ='same')
    x_1 = conv2d_with_Batch(x_1, nbr_kernels = 96, filter_size = (3,3))

    x_2 = conv2d_with_Batch(x, nbr_kernels = 96, filter_size = (1,1))
    x_2 = conv2d_with_Batch(x_2, nbr_kernels = 96, filter_size = (3,3))

    x = concatenate([x_1 , x_2], axis = 3)

    x_1 = conv2d_with_Batch(x, nbr_kernels = 192, filter_size = (3,3) , strides=2)
    x_2 = MaxPool2D(pool_size=(3,3) , strides=(2,2) ) (x)

    x = concatenate([x_1 , x_2], axis = 3)

    return x

# %%
def reduction_A_Block(prev_layer) :
    x_1 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 192, filter_size = (1,1))
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 224, filter_size = (3,3) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 256, filter_size = (3,3) , strides=(2,2))

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 384, filter_size = (3,3) , strides=(2,2))

    x_3 = MaxPool2D(pool_size=(3,3) , strides=(2,2))(prev_layer)

    x = concatenate([x_1 , x_2 , x_3], axis = 3)

    return x

# %%
def reduction_B_Block(prev_layer):
    x_1 = MaxPool2D(pool_size=(3,3) , strides=(2,2))(prev_layer)

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 192, filter_size = (1,1))
    x_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 192, filter_size = (3,3) , strides=(2,2) )

    x_3 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 256, filter_size = (1,1) )
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 256, filter_size = (1,7) , padding='same')
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 320, filter_size = (7,1) , padding='same')
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 320, filter_size = (3,3) , strides=(2,2))

    x = concatenate([x_1 , x_2 , x_3], axis = 3)
    return x

# %%
def InceptionBlock_A(prev_layer): #I'm Here

    x_1 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 64, filter_size = (1,1))
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 96, filter_size = (3,3) , strides=(1,1), padding='same' )
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 96, filter_size = (3,3) , strides=(1,1) , padding='same')

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 64, filter_size = (1,1))
    x_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 96, filter_size = (3,3) , padding='same')

    x_3 = AveragePooling2D(pool_size=(3,3) , strides=1 , padding='same')(prev_layer)
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 96, filter_size = (1,1) , padding='same')

    x_4 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 96, filter_size = (1,1))

    output = concatenate([x_1 , x_2 , x_3 , x_4], axis = 3)

    return output

# %%
def InceptionBlock_B(prev_layer):

    x_1 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 192, filter_size = (1,1))
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 192, filter_size = (7,1) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 224, filter_size = (1,7) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 224, filter_size = (7,1) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 256, filter_size = (1,7), padding='same')

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 192, filter_size = (1,1))
    x_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 224, filter_size = (1,7) , padding='same')
    x_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 256, filter_size = (7,1), padding='same')

    x_3 = AveragePooling2D(pool_size=(3,3) , strides=1 , padding='same')(prev_layer)
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 128, filter_size = (1,1))

    x_4 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 384, filter_size = (1,1))

    output = concatenate([x_1 , x_2 ,x_3, x_4], axis = 3)
    return output

# %%
def InceptionBlock_C(prev_layer):

    x_1 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 384, filter_size = (1,1))
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 448, filter_size = (3,1) , padding='same')
    x_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 512, filter_size = (1,3) , padding='same')
    x_1_1 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 256, filter_size = (1,3), padding='same')
    x_1_2 = conv2d_with_Batch(prev_layer = x_1, nbr_kernels = 256, filter_size = (3,1), padding='same')
    x_1 = concatenate([x_1_1 , x_1_2], axis = 3)

    x_2 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 384, filter_size = (1,1))
    x_2_1 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 256, filter_size = (1,3), padding='same')
    x_2_2 = conv2d_with_Batch(prev_layer = x_2, nbr_kernels = 256, filter_size = (3,1), padding='same')
    x_2 = concatenate([x_2_1 , x_2_2], axis = 3)

    x_3 = MaxPool2D(pool_size=(3,3),strides = 1 , padding='same')(prev_layer)
    x_3 = conv2d_with_Batch(prev_layer = x_3, nbr_kernels = 256, filter_size = 3  , padding='same')

    x_4 = conv2d_with_Batch(prev_layer = prev_layer, nbr_kernels = 256, filter_size = (1,1))

    output = concatenate([x_1 , x_2 , x_3 , x_4], axis = 3)

    return output

# %%
model = InceptionV4()

# Custom Last Stage
x = model.output
# x = tf.keras.layers.GlobalAveragePooling2D()(x)
# x = tf.keras.layers.Dense(1024, activation='relu')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.Dropout(0.5)(x)
# x = tf.keras.layers.Dense(512, activation='relu')(x)
# x = tf.keras.layers.BatchNormalization()(x)
# x = tf.keras.layers.Dropout(0.5)(x)
# x = tf.keras.layers.Dense(64, activation='relu')(x)
# x = tf.keras.layers.BatchNormalization()(x)
predictions = tf.keras.layers.Dense(4, activation='softmax')(x)
model = tf.keras.Model(inputs=model.input, outputs=predictions)

# Compile
sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)
rmsprop = tf.keras.optimizers.RMSprop(learning_rate=0.001)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary
model.summary()
# Out:
# 2023-11-05 15:57:59.495982: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-11-05 15:57:59.496015: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-11-05 15:57:59.496515: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 111, 111, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 111, 111, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 109, 109, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 109, 109, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 109, 109, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 107, 107, 64  18496       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 107, 107, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 107, 107, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 53, 53, 96)   55392       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 53, 53, 96)  384         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 53, 53, 96)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 53, 53, 64)   0           ['activation_2[0][0]']
#
#  concatenate (Concatenate)      (None, 53, 53, 160)  0           ['activation_3[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 53, 53, 64)   10304       ['concatenate[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 53, 53, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 53, 53, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 53, 53, 64)   28736       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 53, 53, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 53, 53, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 53, 53, 64)   28736       ['activation_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 53, 53, 96)   15456       ['concatenate[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 53, 53, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 53, 53, 96)  384         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 53, 53, 64)   0           ['batch_normalization_6[0][0]']
#
#  activation_8 (Activation)      (None, 53, 53, 96)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 51, 51, 96)   55392       ['activation_6[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 51, 51, 96)   83040       ['activation_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 51, 51, 96)  384         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 51, 51, 96)  384         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 51, 51, 96)   0           ['batch_normalization_7[0][0]']
#
#  activation_9 (Activation)      (None, 51, 51, 96)   0           ['batch_normalization_9[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 51, 51, 192)  0           ['activation_7[0][0]',
#                                                                   'activation_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 192)  331968      ['concatenate_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 192)  768        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 25, 25, 192)  0           ['batch_normalization_10[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 192)  0          ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 25, 25, 384)  0           ['activation_10[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 64)   24640       ['concatenate_2[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 25, 25, 64)   24640       ['concatenate_2[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 96)  384         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 25, 25, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_14[0][0]']
#
#  average_pooling2d (AveragePool  (None, 25, 25, 384)  0          ['concatenate_2[0][0]']
#  ing2D)
#
#  conv2d_13 (Conv2D)             (None, 25, 25, 96)   83040       ['activation_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 25, 25, 96)   36960       ['average_pooling2d[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 25, 25, 96)   36960       ['concatenate_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 96)  384         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 25, 25, 96)  384         ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 25, 25, 96)  384         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 25, 25, 96)  384         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_13[0][0]']
#
#  activation_15 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_15[0][0]']
#
#  activation_16 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_16[0][0]']
#
#  activation_17 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_17[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 25, 25, 384)  0           ['activation_13[0][0]',
#                                                                   'activation_15[0][0]',
#                                                                   'activation_16[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 25, 25, 64)   24640       ['concatenate_3[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 25, 25, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 25, 25, 64)   24640       ['concatenate_3[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 25, 25, 96)  384         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 25, 25, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_21[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 25, 25, 384)  0          ['concatenate_3[0][0]']
#  oling2D)
#
#  conv2d_20 (Conv2D)             (None, 25, 25, 96)   83040       ['activation_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 25, 25, 96)   36960       ['average_pooling2d_1[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 25, 25, 96)   36960       ['concatenate_3[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 25, 25, 96)  384         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 25, 25, 96)  384         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 25, 25, 96)  384         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 25, 25, 96)  384         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_20[0][0]']
#
#  activation_22 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_22[0][0]']
#
#  activation_23 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_23[0][0]']
#
#  activation_24 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 25, 25, 384)  0           ['activation_20[0][0]',
#                                                                   'activation_22[0][0]',
#                                                                   'activation_23[0][0]',
#                                                                   'activation_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 25, 25, 64)   24640       ['concatenate_4[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 25, 25, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 25, 25, 64)   24640       ['concatenate_4[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 25, 25, 96)  384         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 25, 25, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_26[0][0]']
#
#  activation_28 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_28[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 25, 25, 384)  0          ['concatenate_4[0][0]']
#  oling2D)
#
#  conv2d_27 (Conv2D)             (None, 25, 25, 96)   83040       ['activation_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 25, 25, 96)   36960       ['average_pooling2d_2[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 25, 25, 96)   36960       ['concatenate_4[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 25, 25, 96)  384         ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 25, 25, 96)  384         ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 25, 25, 96)  384         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 25, 25, 96)  384         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_27[0][0]']
#
#  activation_29 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_29[0][0]']
#
#  activation_30 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_30[0][0]']
#
#  activation_31 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_31[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 25, 25, 384)  0           ['activation_27[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'activation_30[0][0]',
#                                                                   'activation_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 25, 25, 64)   24640       ['concatenate_5[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 25, 25, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 25, 25, 64)   24640       ['concatenate_5[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 25, 25, 96)  384         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 25, 25, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_33[0][0]']
#
#  activation_35 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_35[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 25, 25, 384)  0          ['concatenate_5[0][0]']
#  oling2D)
#
#  conv2d_34 (Conv2D)             (None, 25, 25, 96)   83040       ['activation_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 25, 25, 96)   36960       ['average_pooling2d_3[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 25, 25, 96)   36960       ['concatenate_5[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 25, 25, 96)  384         ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 25, 25, 96)  384         ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 25, 25, 96)  384         ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 25, 25, 96)  384         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_34[0][0]']
#
#  activation_36 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_36[0][0]']
#
#  activation_37 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_37[0][0]']
#
#  activation_38 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_38[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 25, 25, 384)  0           ['activation_34[0][0]',
#                                                                   'activation_36[0][0]',
#                                                                   'activation_37[0][0]',
#                                                                   'activation_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 25, 25, 192)  73920       ['concatenate_6[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 25, 25, 192)  768        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 25, 25, 192)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 25, 25, 224)  387296      ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 25, 25, 224)  896        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 25, 25, 224)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 12, 12, 256)  516352      ['activation_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 12, 12, 384)  1327488     ['concatenate_6[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 12, 12, 384)  1536       ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 12, 12, 256)  0           ['batch_normalization_41[0][0]']
#
#  activation_42 (Activation)     (None, 12, 12, 384)  0           ['batch_normalization_42[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 384)  0          ['concatenate_6[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 12, 12, 1024  0           ['activation_41[0][0]',
#                                 )                                 'activation_42[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 12, 12, 192)  196800      ['concatenate_7[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 12, 12, 192)  768        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 12, 12, 192)  258240      ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 12, 12, 192)  768        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 12, 224)  301280      ['activation_44[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 12, 12, 192)  196800      ['concatenate_7[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 12, 12, 224)  896        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 12, 12, 192)  768        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 12, 12, 224)  0           ['batch_normalization_45[0][0]']
#
#  activation_48 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 12, 12, 224)  351456      ['activation_45[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 12, 12, 224)  301280      ['activation_48[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 12, 12, 224)  896        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 12, 12, 224)  896        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 12, 12, 224)  0           ['batch_normalization_46[0][0]']
#
#  activation_49 (Activation)     (None, 12, 12, 224)  0           ['batch_normalization_49[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 12, 12, 1024  0          ['concatenate_7[0][0]']
#  oling2D)                       )
#
#  conv2d_47 (Conv2D)             (None, 12, 12, 256)  401664      ['activation_46[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 12, 12, 256)  401664      ['activation_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 12, 12, 128)  131200      ['average_pooling2d_4[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 12, 12, 384)  393600      ['concatenate_7[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 12, 12, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 12, 12, 384)  1536       ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 12, 12, 256)  0           ['batch_normalization_47[0][0]']
#
#  activation_50 (Activation)     (None, 12, 12, 256)  0           ['batch_normalization_50[0][0]']
#
#  activation_51 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_51[0][0]']
#
#  activation_52 (Activation)     (None, 12, 12, 384)  0           ['batch_normalization_52[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 12, 12, 1024  0           ['activation_47[0][0]',
#                                 )                                 'activation_50[0][0]',
#                                                                   'activation_51[0][0]',
#                                                                   'activation_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 12, 12, 192)  196800      ['concatenate_8[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 12, 12, 192)  768        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 12, 12, 192)  258240      ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 12, 12, 192)  768        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 12, 12, 224)  301280      ['activation_54[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 12, 12, 192)  196800      ['concatenate_8[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 12, 12, 224)  896        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 12, 12, 192)  768        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 12, 12, 224)  0           ['batch_normalization_55[0][0]']
#
#  activation_58 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 12, 12, 224)  351456      ['activation_55[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 12, 12, 224)  301280      ['activation_58[0][0]']
#
# ...
#
#  batch_normalization_134 (Batch  (None, 5, 5, 384)   1536        ['conv2d_134[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 5, 5, 512)    0           ['batch_normalization_131[0][0]']
#
#  activation_134 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_134[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 5, 5, 256)    393472      ['activation_131[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 5, 5, 256)    393472      ['activation_131[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 5, 5, 256)    295168      ['activation_134[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 5, 5, 256)    295168      ['activation_134[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 5, 5, 1536)  0           ['concatenate_18[0][0]']
#
#  batch_normalization_132 (Batch  (None, 5, 5, 256)   1024        ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 5, 5, 256)   1024        ['conv2d_133[0][0]']
#  Normalization)
#
#  batch_normalization_135 (Batch  (None, 5, 5, 256)   1024        ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_136 (Batch  (None, 5, 5, 256)   1024        ['conv2d_136[0][0]']
#  Normalization)
#
#  conv2d_137 (Conv2D)            (None, 5, 5, 256)    3539200     ['max_pooling2d_5[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 5, 5, 256)    393472      ['concatenate_18[0][0]']
#
#  activation_132 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_132[0][0]']
#
#  activation_133 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_133[0][0]']
#
#  activation_135 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_135[0][0]']
#
#  activation_136 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_136[0][0]']
#
#  batch_normalization_137 (Batch  (None, 5, 5, 256)   1024        ['conv2d_137[0][0]']
#  Normalization)
#
#  batch_normalization_138 (Batch  (None, 5, 5, 256)   1024        ['conv2d_138[0][0]']
#  Normalization)
#
#  concatenate_19 (Concatenate)   (None, 5, 5, 512)    0           ['activation_132[0][0]',
#                                                                   'activation_133[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 5, 5, 512)    0           ['activation_135[0][0]',
#                                                                   'activation_136[0][0]']
#
#  activation_137 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_137[0][0]']
#
#  activation_138 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_138[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 5, 5, 1536)   0           ['concatenate_19[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 5, 5, 384)    590208      ['concatenate_21[0][0]']
#
#  batch_normalization_139 (Batch  (None, 5, 5, 384)   1536        ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_139[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 5, 5, 448)    516544      ['activation_139[0][0]']
#
#  batch_normalization_140 (Batch  (None, 5, 5, 448)   1792        ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_140[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 5, 5, 512)    688640      ['activation_140[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 5, 5, 384)    590208      ['concatenate_21[0][0]']
#
#  batch_normalization_141 (Batch  (None, 5, 5, 512)   2048        ['conv2d_141[0][0]']
#  Normalization)
#
#  batch_normalization_144 (Batch  (None, 5, 5, 384)   1536        ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 5, 5, 512)    0           ['batch_normalization_141[0][0]']
#
#  activation_144 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_144[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 5, 5, 256)    393472      ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 5, 5, 256)    393472      ['activation_141[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 5, 5, 256)    295168      ['activation_144[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 5, 5, 256)    295168      ['activation_144[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 5, 5, 1536)  0           ['concatenate_21[0][0]']
#
#  batch_normalization_142 (Batch  (None, 5, 5, 256)   1024        ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 5, 5, 256)   1024        ['conv2d_143[0][0]']
#  Normalization)
#
#  batch_normalization_145 (Batch  (None, 5, 5, 256)   1024        ['conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_146 (Batch  (None, 5, 5, 256)   1024        ['conv2d_146[0][0]']
#  Normalization)
#
#  conv2d_147 (Conv2D)            (None, 5, 5, 256)    3539200     ['max_pooling2d_6[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 5, 5, 256)    393472      ['concatenate_21[0][0]']
#
#  activation_142 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_142[0][0]']
#
#  activation_143 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_143[0][0]']
#
#  activation_145 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_145[0][0]']
#
#  activation_146 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_146[0][0]']
#
#  batch_normalization_147 (Batch  (None, 5, 5, 256)   1024        ['conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_148 (Batch  (None, 5, 5, 256)   1024        ['conv2d_148[0][0]']
#  Normalization)
#
#  concatenate_22 (Concatenate)   (None, 5, 5, 512)    0           ['activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 5, 5, 512)    0           ['activation_145[0][0]',
#                                                                   'activation_146[0][0]']
#
#  activation_147 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_147[0][0]']
#
#  activation_148 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_148[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 5, 5, 1536)   0           ['concatenate_22[0][0]',
#                                                                   'concatenate_23[0][0]',
#                                                                   'activation_147[0][0]',
#                                                                   'activation_148[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1536)        0           ['concatenate_24[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1536)         2360832     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 1536)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1000)         1537000     ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 4)            4004        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 54,609,516
# Trainable params: 54,546,284
# Non-trainable params: 63,232
# __________________________________________________________________________________________________

# %%
filepath = 'models/PCD-test-no-aug.h5'

modelCheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath,
    monitor = 'val_accuracy',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False,
    mode = 'max',
    save_freq = 'epoch'
)
earlyStopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=25,
    verbose=1,
    mode='max'
)
callbacksList = [modelCheckpoint, earlyStopping]
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=100,
                    callbacks = callbacksList,
                    verbose=1)
# Out:
# Epoch 1/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1393 - accuracy: 0.4780
# Epoch 1: val_accuracy improved from -inf to 0.16800, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 26s 1s/step - loss: 1.1393 - accuracy: 0.4780 - val_loss: 274.2018 - val_accuracy: 0.1680
# Epoch 2/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0879 - accuracy: 0.4551
# Epoch 2: val_accuracy did not improve from 0.16800
# 20/20 [==============================] - 24s 1s/step - loss: 1.0879 - accuracy: 0.4551 - val_loss: 31.7745 - val_accuracy: 0.1680
# Epoch 3/100
# 20/20 [==============================] - ETA: 0s - loss: 1.3675 - accuracy: 0.4943
# Epoch 3: val_accuracy did not improve from 0.16800
# 20/20 [==============================] - 23s 1s/step - loss: 1.3675 - accuracy: 0.4943 - val_loss: 303.5342 - val_accuracy: 0.1680
# Epoch 4/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0449 - accuracy: 0.5188
# Epoch 4: val_accuracy did not improve from 0.16800
# 20/20 [==============================] - 23s 1s/step - loss: 1.0449 - accuracy: 0.5188 - val_loss: 39.7990 - val_accuracy: 0.1680
# Epoch 5/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9915 - accuracy: 0.5318
# Epoch 5: val_accuracy did not improve from 0.16800
# 20/20 [==============================] - 23s 1s/step - loss: 0.9915 - accuracy: 0.5318 - val_loss: 62.0123 - val_accuracy: 0.1680
# Epoch 6/100
# 20/20 [==============================] - ETA: 0s - loss: 1.7672 - accuracy: 0.5204
# Epoch 6: val_accuracy did not improve from 0.16800
# 20/20 [==============================] - 23s 1s/step - loss: 1.7672 - accuracy: 0.5204 - val_loss: 3.8823 - val_accuracy: 0.1680
# Epoch 7/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1450 - accuracy: 0.4535
# Epoch 7: val_accuracy did not improve from 0.16800
# 20/20 [==============================] - 23s 1s/step - loss: 1.1450 - accuracy: 0.4535 - val_loss: 4.9358 - val_accuracy: 0.1680
# Epoch 8/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1921 - accuracy: 0.5041
# Epoch 8: val_accuracy improved from 0.16800 to 0.28800, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.1921 - accuracy: 0.5041 - val_loss: 1.4480 - val_accuracy: 0.2880
# Epoch 9/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9406 - accuracy: 0.5318
# Epoch 9: val_accuracy did not improve from 0.28800
# 20/20 [==============================] - 23s 1s/step - loss: 0.9406 - accuracy: 0.5318 - val_loss: 1.8645 - val_accuracy: 0.2880
# Epoch 10/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9508 - accuracy: 0.5514
# Epoch 10: val_accuracy did not improve from 0.28800
# 20/20 [==============================] - 22s 1s/step - loss: 0.9508 - accuracy: 0.5514 - val_loss: 3.1983 - val_accuracy: 0.2880
# Epoch 11/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1401 - accuracy: 0.4633
# Epoch 11: val_accuracy did not improve from 0.28800
# 20/20 [==============================] - 22s 1s/step - loss: 1.1401 - accuracy: 0.4633 - val_loss: 1.6656 - val_accuracy: 0.2880
# Epoch 12/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0730 - accuracy: 0.4633
# Epoch 12: val_accuracy did not improve from 0.28800
# 20/20 [==============================] - 23s 1s/step - loss: 1.0730 - accuracy: 0.4633 - val_loss: 1.6569 - val_accuracy: 0.2880
# Epoch 13/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9925 - accuracy: 0.5188
# Epoch 13: val_accuracy did not improve from 0.28800
# 20/20 [==============================] - 23s 1s/step - loss: 0.9925 - accuracy: 0.5188 - val_loss: 2.0919 - val_accuracy: 0.2880
# Epoch 14/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0804 - accuracy: 0.4910
# Epoch 14: val_accuracy did not improve from 0.28800
# 20/20 [==============================] - 23s 1s/step - loss: 1.0804 - accuracy: 0.4910 - val_loss: 1.8748 - val_accuracy: 0.2640
# Epoch 15/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1090 - accuracy: 0.4910
# Epoch 15: val_accuracy improved from 0.28800 to 0.38400, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.1090 - accuracy: 0.4910 - val_loss: 1.6640 - val_accuracy: 0.3840
# Epoch 16/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1051 - accuracy: 0.5024
# Epoch 16: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 23s 1s/step - loss: 1.1051 - accuracy: 0.5024 - val_loss: 1.8433 - val_accuracy: 0.2880
# Epoch 17/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0356 - accuracy: 0.4812
# Epoch 17: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 22s 1s/step - loss: 1.0356 - accuracy: 0.4812 - val_loss: 1.7998 - val_accuracy: 0.3840
# Epoch 18/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0378 - accuracy: 0.5057
# Epoch 18: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 22s 1s/step - loss: 1.0378 - accuracy: 0.5057 - val_loss: 1.8953 - val_accuracy: 0.3840
# Epoch 19/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9657 - accuracy: 0.4878
# Epoch 19: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 22s 1s/step - loss: 0.9657 - accuracy: 0.4878 - val_loss: 2.6059 - val_accuracy: 0.3840
# Epoch 20/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0066 - accuracy: 0.5171
# Epoch 20: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 22s 1s/step - loss: 1.0066 - accuracy: 0.5171 - val_loss: 2.3314 - val_accuracy: 0.3840
# Epoch 21/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9895 - accuracy: 0.5220
# Epoch 21: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 22s 1s/step - loss: 0.9895 - accuracy: 0.5220 - val_loss: 2.5586 - val_accuracy: 0.3840
# Epoch 22/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9150 - accuracy: 0.5432
# Epoch 22: val_accuracy did not improve from 0.38400
# 20/20 [==============================] - 22s 1s/step - loss: 0.9150 - accuracy: 0.5432 - val_loss: 1.9932 - val_accuracy: 0.2880
# Epoch 23/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9223 - accuracy: 0.5808
# Epoch 23: val_accuracy improved from 0.38400 to 0.39200, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.9223 - accuracy: 0.5808 - val_loss: 1.4095 - val_accuracy: 0.3920
# Epoch 24/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9596 - accuracy: 0.5204
# Epoch 24: val_accuracy improved from 0.39200 to 0.44800, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.9596 - accuracy: 0.5204 - val_loss: 1.4438 - val_accuracy: 0.4480
# Epoch 25/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9105 - accuracy: 0.5775
# Epoch 25: val_accuracy did not improve from 0.44800
# 20/20 [==============================] - 23s 1s/step - loss: 0.9105 - accuracy: 0.5775 - val_loss: 1.4047 - val_accuracy: 0.4480
# Epoch 26/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8067 - accuracy: 0.5954
# Epoch 26: val_accuracy did not improve from 0.44800
# 20/20 [==============================] - 22s 1s/step - loss: 0.8067 - accuracy: 0.5954 - val_loss: 1.3795 - val_accuracy: 0.4400
# Epoch 27/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0915 - accuracy: 0.5188
# Epoch 27: val_accuracy improved from 0.44800 to 0.45600, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.0915 - accuracy: 0.5188 - val_loss: 0.9316 - val_accuracy: 0.4560
# Epoch 28/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0033 - accuracy: 0.4780
# Epoch 28: val_accuracy improved from 0.45600 to 0.55200, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.0033 - accuracy: 0.4780 - val_loss: 0.9492 - val_accuracy: 0.5520
# Epoch 29/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9379 - accuracy: 0.5465
# Epoch 29: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 23s 1s/step - loss: 0.9379 - accuracy: 0.5465 - val_loss: 1.0681 - val_accuracy: 0.5040
# Epoch 30/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8608 - accuracy: 0.5775
# Epoch 30: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.8608 - accuracy: 0.5775 - val_loss: 1.3454 - val_accuracy: 0.4240
# Epoch 31/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8864 - accuracy: 0.5889
# Epoch 31: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.8864 - accuracy: 0.5889 - val_loss: 1.1493 - val_accuracy: 0.5200
# Epoch 32/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8976 - accuracy: 0.5661
# Epoch 32: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.8976 - accuracy: 0.5661 - val_loss: 0.9712 - val_accuracy: 0.5360
# Epoch 33/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9295 - accuracy: 0.5824
# Epoch 33: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.9295 - accuracy: 0.5824 - val_loss: 0.9234 - val_accuracy: 0.4240
# Epoch 34/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8381 - accuracy: 0.5808
# Epoch 34: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.8381 - accuracy: 0.5808 - val_loss: 1.0082 - val_accuracy: 0.4080
# Epoch 35/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0869 - accuracy: 0.4649
# Epoch 35: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 1.0869 - accuracy: 0.4649 - val_loss: 0.9573 - val_accuracy: 0.4480
# Epoch 36/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8779 - accuracy: 0.5677
# Epoch 36: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.8779 - accuracy: 0.5677 - val_loss: 0.7871 - val_accuracy: 0.5360
# Epoch 37/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.6248
# Epoch 37: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.7398 - accuracy: 0.6248 - val_loss: 1.0178 - val_accuracy: 0.4720
# Epoch 38/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7662 - accuracy: 0.6281
# Epoch 38: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.7662 - accuracy: 0.6281 - val_loss: 1.7347 - val_accuracy: 0.2240
# Epoch 39/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8612 - accuracy: 0.6411
# Epoch 39: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 23s 1s/step - loss: 0.8612 - accuracy: 0.6411 - val_loss: 2.3077 - val_accuracy: 0.2160
# Epoch 40/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8220 - accuracy: 0.6183
# Epoch 40: val_accuracy did not improve from 0.55200
# 20/20 [==============================] - 22s 1s/step - loss: 0.8220 - accuracy: 0.6183 - val_loss: 1.8074 - val_accuracy: 0.2400
# Epoch 41/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8129 - accuracy: 0.6003
# Epoch 41: val_accuracy improved from 0.55200 to 0.58400, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.8129 - accuracy: 0.6003 - val_loss: 0.8462 - val_accuracy: 0.5840
# Epoch 42/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8655 - accuracy: 0.6036
# Epoch 42: val_accuracy did not improve from 0.58400
# 20/20 [==============================] - 22s 1s/step - loss: 0.8655 - accuracy: 0.6036 - val_loss: 1.7280 - val_accuracy: 0.1680
# Epoch 43/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7906 - accuracy: 0.6525
# Epoch 43: val_accuracy did not improve from 0.58400
# 20/20 [==============================] - 22s 1s/step - loss: 0.7906 - accuracy: 0.6525 - val_loss: 1.6847 - val_accuracy: 0.3440
# Epoch 44/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7590 - accuracy: 0.6346
# Epoch 44: val_accuracy did not improve from 0.58400
# 20/20 [==============================] - 22s 1s/step - loss: 0.7590 - accuracy: 0.6346 - val_loss: 1.2629 - val_accuracy: 0.3600
# Epoch 45/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7763 - accuracy: 0.6362
# Epoch 45: val_accuracy did not improve from 0.58400
# 20/20 [==============================] - 22s 1s/step - loss: 0.7763 - accuracy: 0.6362 - val_loss: 1.0002 - val_accuracy: 0.4240
# Epoch 46/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6657 - accuracy: 0.6542
# Epoch 46: val_accuracy improved from 0.58400 to 0.64000, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.6657 - accuracy: 0.6542 - val_loss: 0.7570 - val_accuracy: 0.6400
# Epoch 47/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7621 - accuracy: 0.6330
# Epoch 47: val_accuracy improved from 0.64000 to 0.69600, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.7621 - accuracy: 0.6330 - val_loss: 0.6775 - val_accuracy: 0.6960
# Epoch 48/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6505 - accuracy: 0.6688
# Epoch 48: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 23s 1s/step - loss: 0.6505 - accuracy: 0.6688 - val_loss: 1.0169 - val_accuracy: 0.4800
# Epoch 49/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6193 - accuracy: 0.6770
# Epoch 49: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.6193 - accuracy: 0.6770 - val_loss: 1.3814 - val_accuracy: 0.4400
# Epoch 50/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6068 - accuracy: 0.7243
# Epoch 50: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.6068 - accuracy: 0.7243 - val_loss: 0.8311 - val_accuracy: 0.5920
# Epoch 51/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5366 - accuracy: 0.7374
# Epoch 51: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.5366 - accuracy: 0.7374 - val_loss: 1.2723 - val_accuracy: 0.5200
# Epoch 52/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5456 - accuracy: 0.7390
# Epoch 52: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.5456 - accuracy: 0.7390 - val_loss: 1.0403 - val_accuracy: 0.5680
# Epoch 53/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6173 - accuracy: 0.7357
# Epoch 53: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.6173 - accuracy: 0.7357 - val_loss: 0.8180 - val_accuracy: 0.6240
# Epoch 54/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5497 - accuracy: 0.7227
# Epoch 54: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.5497 - accuracy: 0.7227 - val_loss: 0.7504 - val_accuracy: 0.6480
# Epoch 55/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.7635
# Epoch 55: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.5001 - accuracy: 0.7635 - val_loss: 1.0568 - val_accuracy: 0.5680
# Epoch 56/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5484 - accuracy: 0.7357
# Epoch 56: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.5484 - accuracy: 0.7357 - val_loss: 1.1537 - val_accuracy: 0.5120
# Epoch 57/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.7488
# Epoch 57: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.6177 - accuracy: 0.7488 - val_loss: 1.0479 - val_accuracy: 0.5840
# Epoch 58/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6243 - accuracy: 0.7504
# Epoch 58: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.6243 - accuracy: 0.7504 - val_loss: 1.0830 - val_accuracy: 0.4240
# Epoch 59/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4817 - accuracy: 0.7912
# Epoch 59: val_accuracy did not improve from 0.69600
# 20/20 [==============================] - 22s 1s/step - loss: 0.4817 - accuracy: 0.7912 - val_loss: 1.2648 - val_accuracy: 0.5440
# Epoch 60/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.8532
# Epoch 60: val_accuracy improved from 0.69600 to 0.72000, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.4059 - accuracy: 0.8532 - val_loss: 0.6960 - val_accuracy: 0.7200
# Epoch 61/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3859 - accuracy: 0.8597
# Epoch 61: val_accuracy did not improve from 0.72000
# 20/20 [==============================] - 22s 1s/step - loss: 0.3859 - accuracy: 0.8597 - val_loss: 1.9393 - val_accuracy: 0.3840
# Epoch 62/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5223 - accuracy: 0.8059
# Epoch 62: val_accuracy did not improve from 0.72000
# 20/20 [==============================] - 22s 1s/step - loss: 0.5223 - accuracy: 0.8059 - val_loss: 1.2686 - val_accuracy: 0.4080
# Epoch 63/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4671 - accuracy: 0.8075
# Epoch 63: val_accuracy did not improve from 0.72000
# 20/20 [==============================] - 22s 1s/step - loss: 0.4671 - accuracy: 0.8075 - val_loss: 2.0217 - val_accuracy: 0.3200
# Epoch 64/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3606 - accuracy: 0.8728
# Epoch 64: val_accuracy did not improve from 0.72000
# 20/20 [==============================] - 22s 1s/step - loss: 0.3606 - accuracy: 0.8728 - val_loss: 1.8672 - val_accuracy: 0.3760
# Epoch 65/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8679
# Epoch 65: val_accuracy improved from 0.72000 to 0.72800, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.4146 - accuracy: 0.8679 - val_loss: 0.6577 - val_accuracy: 0.7280
# Epoch 66/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.8238
# Epoch 66: val_accuracy did not improve from 0.72800
# 20/20 [==============================] - 23s 1s/step - loss: 0.4964 - accuracy: 0.8238 - val_loss: 0.7312 - val_accuracy: 0.6560
# Epoch 67/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5164 - accuracy: 0.8434
# Epoch 67: val_accuracy improved from 0.72800 to 0.80800, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.5164 - accuracy: 0.8434 - val_loss: 0.5106 - val_accuracy: 0.8080
# Epoch 68/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4892 - accuracy: 0.8287
# Epoch 68: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.4892 - accuracy: 0.8287 - val_loss: 0.5270 - val_accuracy: 0.7840
# Epoch 69/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3096 - accuracy: 0.8923
# Epoch 69: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.3096 - accuracy: 0.8923 - val_loss: 1.0354 - val_accuracy: 0.5760
# Epoch 70/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8597
# Epoch 70: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.3368 - accuracy: 0.8597 - val_loss: 0.7006 - val_accuracy: 0.7840
# Epoch 71/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3886 - accuracy: 0.8907
# Epoch 71: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.3886 - accuracy: 0.8907 - val_loss: 1.0153 - val_accuracy: 0.6960
# Epoch 72/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3748 - accuracy: 0.8907
# Epoch 72: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.3748 - accuracy: 0.8907 - val_loss: 0.9045 - val_accuracy: 0.6800
# Epoch 73/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.8532
# Epoch 73: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.4557 - accuracy: 0.8532 - val_loss: 1.1663 - val_accuracy: 0.4000
# Epoch 74/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.7618
# Epoch 74: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.6616 - accuracy: 0.7618 - val_loss: 0.7922 - val_accuracy: 0.6000
# Epoch 75/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5676 - accuracy: 0.7896
# Epoch 75: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.5676 - accuracy: 0.7896 - val_loss: 0.8111 - val_accuracy: 0.6160
# Epoch 76/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4249 - accuracy: 0.8728
# Epoch 76: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.4249 - accuracy: 0.8728 - val_loss: 0.7778 - val_accuracy: 0.6880
# Epoch 77/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4421 - accuracy: 0.8728
# Epoch 77: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.4421 - accuracy: 0.8728 - val_loss: 0.6945 - val_accuracy: 0.7120
# Epoch 78/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3803 - accuracy: 0.8793
# Epoch 78: val_accuracy did not improve from 0.80800
# 20/20 [==============================] - 22s 1s/step - loss: 0.3803 - accuracy: 0.8793 - val_loss: 1.9714 - val_accuracy: 0.5680
# Epoch 79/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4597 - accuracy: 0.8450
# Epoch 79: val_accuracy improved from 0.80800 to 0.81600, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.4597 - accuracy: 0.8450 - val_loss: 0.5534 - val_accuracy: 0.8160
# Epoch 80/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3526 - accuracy: 0.8793
# Epoch 80: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.3526 - accuracy: 0.8793 - val_loss: 2.0015 - val_accuracy: 0.4880
# Epoch 81/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9347
# Epoch 81: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.2163 - accuracy: 0.9347 - val_loss: 0.9158 - val_accuracy: 0.7520
# Epoch 82/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4554 - accuracy: 0.8809
# Epoch 82: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.4554 - accuracy: 0.8809 - val_loss: 223.8307 - val_accuracy: 0.1680
# Epoch 83/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4990 - accuracy: 0.8532
# Epoch 83: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.4990 - accuracy: 0.8532 - val_loss: 33.7927 - val_accuracy: 0.1680
# Epoch 84/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.8369
# Epoch 84: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.4443 - accuracy: 0.8369 - val_loss: 6.0307 - val_accuracy: 0.2000
# Epoch 85/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3502 - accuracy: 0.8940
# Epoch 85: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.3502 - accuracy: 0.8940 - val_loss: 1.2614 - val_accuracy: 0.5440
# Epoch 86/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.8157
# Epoch 86: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.4604 - accuracy: 0.8157 - val_loss: 1.4213 - val_accuracy: 0.5120
# Epoch 87/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3980 - accuracy: 0.8777
# Epoch 87: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.3980 - accuracy: 0.8777 - val_loss: 2.1441 - val_accuracy: 0.4480
# Epoch 88/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2680 - accuracy: 0.9217
# Epoch 88: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.2680 - accuracy: 0.9217 - val_loss: 0.6446 - val_accuracy: 0.7680
# Epoch 89/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3133 - accuracy: 0.9103
# Epoch 89: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.3133 - accuracy: 0.9103 - val_loss: 0.6807 - val_accuracy: 0.7920
# Epoch 90/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.9184
# Epoch 90: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.2536 - accuracy: 0.9184 - val_loss: 0.5947 - val_accuracy: 0.8080
# Epoch 91/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.9347
# Epoch 91: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.2070 - accuracy: 0.9347 - val_loss: 1.4617 - val_accuracy: 0.7040
# Epoch 92/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.9364
# Epoch 92: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.2574 - accuracy: 0.9364 - val_loss: 0.8552 - val_accuracy: 0.7440
# Epoch 93/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2477 - accuracy: 0.9184
# Epoch 93: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.2477 - accuracy: 0.9184 - val_loss: 0.8894 - val_accuracy: 0.8000
# Epoch 94/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5352 - accuracy: 0.8287
# Epoch 94: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.5352 - accuracy: 0.8287 - val_loss: 0.8381 - val_accuracy: 0.6400
# Epoch 95/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5037 - accuracy: 0.8042
# Epoch 95: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.5037 - accuracy: 0.8042 - val_loss: 0.6070 - val_accuracy: 0.7760
# Epoch 96/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.9086
# Epoch 96: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.3188 - accuracy: 0.9086 - val_loss: 1.0706 - val_accuracy: 0.6480
# Epoch 97/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.9054
# Epoch 97: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.2789 - accuracy: 0.9054 - val_loss: 1.0048 - val_accuracy: 0.7120
# Epoch 98/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.9168
# Epoch 98: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.2632 - accuracy: 0.9168 - val_loss: 1.6778 - val_accuracy: 0.5440
# Epoch 99/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3994 - accuracy: 0.8793
# Epoch 99: val_accuracy did not improve from 0.81600
# 20/20 [==============================] - 22s 1s/step - loss: 0.3994 - accuracy: 0.8793 - val_loss: 0.6695 - val_accuracy: 0.7680
# Epoch 100/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2334 - accuracy: 0.9250
# Epoch 100: val_accuracy improved from 0.81600 to 0.83200, saving model to models/PCD-test-no-aug.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.2334 - accuracy: 0.9250 - val_loss: 0.5381 - val_accuracy: 0.8320

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.show()
print("")

plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()

# %%
load_model = tf.keras.models.load_model('models/PCD-test-no-aug.h5')

# %%
x, y = test_generator.next()
print("x: ",len(x)," y: ",len(y))
# Out:
# x:  190  y:  190

# %%
pred = load_model.predict(x)

y_test = []
for i in pred:
    y_test.append(np.argmax(i))

y_pred = []
for i in y:
    y_pred.append(np.argmax(i))
# Out:
# 6/6 [==============================] - 5s 447ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

sns.set(rc = {'figure.figsize':(15,10)})
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')

ax.set_title('Seaborn Confusion Matrix\n');
ax.set_xlabel('Result Predict(y_test)')
ax.set_ylabel('Actual Values(y_pred) ');

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.78        76
#            1       0.84      0.79      0.81        33
#            2       1.00      1.00      1.00        33
#            3       0.74      0.83      0.78        48
#
#     accuracy                           0.83       190
#    macro avg       0.85      0.85      0.85       190
# weighted avg       0.83      0.83      0.83       190

# %%
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

precision2 = precision_score(y_test, y_pred, average='micro')
recall2 = recall_score(y_test, y_pred, average='micro')
f1score2 = f1_score(y_test, y_pred, average='micro')

print(f"Precision = {precision2}")
print(f"Recall = {recall2}")
print(f"F1 Score = {f1score2}")
# Out:
# Precision = 0.8263157894736842
# Recall = 0.8263157894736842
# F1 Score = 0.8263157894736841
